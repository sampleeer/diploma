# %%
from copy import deepcopy
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import Image
from skimage.draw import line, disk
from scipy.optimize import minimize
from calorimeter import calo_importer
import scipy.io
import cvxpy as cp
from scipy.sparse import csr_matrix
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from math import atan2, acos
from sklearn.linear_model import LinearRegression

# %%
pip install scikit-learn

# %%
import scipy.io
calorimeter_response_protons = scipy.io.loadmat("calorimeter_response.mat")
secondary_protons = scipy.io.loadmat("secondary.mat")
calorimeter_response_antiprotons = scipy.io.loadmat("calorimeter_response_antiprotons.mat")
secondary_antiprotons = scipy.io.loadmat("secondary_antiprotons.mat")

# %%
data = deepcopy(calorimeter_response_protons)

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Tue May 21 14:33:20 2024',
#  '__version__': '1.0',
#  '__globals__': [],
#  'E_0': array([[1745.39, 2859.57, 1433.08, ..., 4222.97, 6916.87, 6589.18]]),
#  'X_0': array([[-72.9942, -37.1207, -69.118 , ...,  47.0039, -61.3038, -20.493 ]]),
#  'Y_0': array([[ 11.0633, -85.0243, -33.8059, ...,  22.3615,  62.9135,  47.3031]]),
#  'theta_0': array([[0.503032 , 0.56611  , 0.0662649, ..., 0.768048 , 0.606821 ,
#          0.0842612]]),
#  'phi_0': array([[0.17943, 4.36732, 2.73976, ..., 3.22291, 3.3012 , 3.24898]]),
#  'Z_end': array([[139.821  ,   3.40819, 213.576  , ..., 101.     , 125.106  ,
#          213.576  ]]),
#  'last_process': array(['protonInelastic', 'protonInelastic', 'Transportation ', ...,
#         'protonInelastic', 'Transportation ', 'Transportation '],
#        dtype='<U15'),
#  'event_ID': array([[   0.,    0.,    0., ..., 9999., 9999., 9999.]]),
#  'layer': array([[ 0.,  1.,  2., ..., 41., 42., 43.]]),
#  'index_along_x': array([[19., 20., 21., ..., 34., 34., 34.]]),
#  'index_along_y': array([[52., 52., 52., ..., 65., 65., 65.]]),
#  'energy_release': array([[0.150545 , 0.167601 , 0.23037  , ..., 0.0982744, 0.0995915,
#          0.0988736]])}

# %%
X = data['X_0']
shape_X = X.shape
shape_X
# Out:
# (1, 10000)

# %%
#np.set_printoptions(threshold=np.inf)

last_proc= data['last_process']
last_proc[12]
# Out:
# 'protonInelastic'

# %%
plane_yz_np_data = np.array(data['X_0'])
plane_xz_np_data = np.array(data['Y_0'])
plane_yz_np_data
# Out:
# array([[-72.9942, -37.1207, -69.118 , ...,  47.0039, -61.3038, -20.493 ]])

# %%
secondary_protons
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Tue May 21 14:33:22 2024',
#  '__version__': '1.0',
#  '__globals__': [],
#  'secondary': array([[array([[ 1.00000e+00,  2.21200e+03, -7.29942e+01,  1.10633e+01,
#                  -1.00000e+00,  1.74539e+03],
#                 [ 1.00000e+00,  2.21200e+03, -7.24528e+01,  1.11615e+01,
#                   0.00000e+00,  1.74539e+03],
#                 [ 1.00000e+00,  2.21200e+03, -7.22470e+01,  1.11989e+01,
#                   3.80000e-01,  1.74523e+03],
#                 ...,
#                 [ 2.00000e+00,  1.10000e+01, -5.99821e+01,  1.37972e+01,
#                   2.41625e+01,  1.38636e-01],
#                 [ 2.00000e+00,  1.10000e+01, -5.99977e+01,  1.38232e+01,
#                   2.41018e+01,  9.32497e-02],
#                 [ 2.00000e+00,  1.10000e+01, -6.00138e+01,  1.38341e+01,
#                   2.40692e+01,  0.00000e+00]])                          ,
#          array([[ 1.00000e+00,  2.21200e+03, -3.71207e+01, -8.50243e+01,
#                  -1.00000e+00,  2.85957e+03],
#                 [ 1.00000e+00,  2.21200e+03, -3.73357e+01, -8.56223e+01,
#                   0.00000e+00,  2.85957e+03],
#                 [ 1.00000e+00,  2.21200e+03, -3.74174e+01, -8.58496e+01,
#                   3.80000e-01,  2.85940e+03],
#                 ...,
#                 [ 3.00000e+00,  2.21200e+03, -7.68656e+01, -1.22481e+02,
#                   1.66100e+01,  3.34928e+02],
#                 [ 3.00000e+00,  2.21200e+03, -7.74341e+01, -1.23000e+02,
#                   1.67932e+01,  3.34457e+02],
#                 [ 3.00000e+00,  2.21200e+03, -1.04397e+02, -1.47600e+02,
#                   2.54968e+01,  3.34457e+02]])                          ,
#          array([[ 1.00000e+00,  2.21200e+03, -6.91180e+01, -3.38059e+01,
#                  -1.00000e+00,  1.43308e+03],
#                 [ 1.00000e+00,  2.21200e+03, -6.91791e+01, -3.37800e+01,
#                   0.00000e+00,  1.43308e+03],
#                 [ 1.00000e+00,  2.21200e+03, -6.92023e+01, -3.37701e+01,
#                   3.80000e-01,  1.43298e+03],
#                 ...,
#                 [ 2.00000e+00,  1.10000e+01, -7.20191e+01, -3.23055e+01,
#                   5.81627e+01,  1.16849e-01],
#                 [ 2.00000e+00,  1.10000e+01, -7.20414e+01, -3.23032e+01,
#                   5.81174e+01,  5.71682e-02],
#                 [ 2.00000e+00,  1.10000e+01, -7.20480e+01, -3.22963e+01,
#                   5.81061e+01,  0.00000e+00]])                          ,
#          ...,
#          array([[ 1.00000e+00,  2.21200e+03,  4.70039e+01,  2.23615e+01,
#                  -1.00000e+00,  4.22297e+03],
#                 [ 1.00000e+00,  2.21200e+03,  4.60412e+01,  2.22831e+01,
#                   0.00000e+00,  4.22297e+03],
#                 [ 1.00000e+00,  2.21200e+03,  4.56754e+01,  2.22533e+01,
#                   3.80000e-01,  4.22282e+03],
#                 ...,
#                 [ 2.00000e+00,  1.10000e+01,  4.31887e+01,  2.20504e+01,
#                   2.96049e+00,  3.06889e+00],
#                 [ 2.00000e+00,  1.10000e+01,  4.31202e+01,  2.19768e+01,
#                   3.12589e+00,  1.47887e+00],
#                 [ 2.00000e+00,  1.10000e+01,  4.31203e+01,  2.20407e+01,
#                   3.10638e+00,  0.00000e+00]])                          ,
#          array([[ 1.00000e+00,  2.21200e+03, -6.13038e+01,  6.29135e+01,
#                  -1.00000e+00,  6.91687e+03],
#                 [ 1.00000e+00,  2.21200e+03, -6.19891e+01,  6.28031e+01,
#                  -1.11022e-16,  6.91687e+03],
#                 [ 1.00000e+00,  2.21200e+03, -6.22496e+01,  6.27612e+01,
#                   3.80000e-01,  6.91671e+03],
#                 ...,
#                 [ 2.00000e+00,  1.10000e+01, -7.41334e+01,  6.02199e+01,
#                   1.77032e+01,  1.52095e-01],
#                 [ 2.00000e+00,  1.10000e+01, -7.41665e+01,  6.02293e+01,
#                   1.76531e+01,  1.29121e-01],
#                 [ 2.00000e+00,  1.10000e+01, -7.41974e+01,  6.02321e+01,
#                   1.76012e+01,  0.00000e+00]])                          ,
#          array([[ 1.00000e+00,  2.21200e+03, -2.04930e+01,  4.73031e+01,
#                  -1.00000e+00,  6.58918e+03],
#                 [ 1.00000e+00,  2.21200e+03, -2.05770e+01,  4.72940e+01,
#                   0.00000e+00,  6.58918e+03],
#                 [ 1.00000e+00,  2.21200e+03, -2.06089e+01,  4.72906e+01,
#                   3.80000e-01,  6.58903e+03],
#                 ...,
#                 [ 2.00000e+00,  1.10000e+01, -2.28704e+01,  4.71034e+01,
#                   3.10932e+01,  6.55342e-01],
#                 [ 2.00000e+00,  1.10000e+01, -2.28224e+01,  4.71689e+01,
#                   3.14469e+01,  5.35865e-01],
#                 [ 2.00000e+00,  1.10000e+01, -2.30604e+01,  4.71796e+01,
#                   3.20271e+01,  0.00000e+00]])                          ]],
#        dtype=object)}

# %%
sys.path.append(r'/Users/pavelnehaenko/Downloads/pamela-master/src')

# %%
fnum = 1
dpath = '/Users/pavelnehaenko/Desktop/me/kursach/simulation' 
siminfofile = 'protons/SimInfo/SimInfo_pr_0p1_1500_rig_F0p8_10000000_1.mat'.format(fnum)
siminfo_data = scipy.io.loadmat(os.path.join(dpath, siminfofile), variable_names=['caloplaneint', 'fTHETA', 'fPHI'])

# %%
siminfo_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Sun Dec 26 08:55:45 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'caloplaneint': array([[ 9],
#         [44],
#         [44],
#         ...,
#         [31],
#         [44],
#         [44]], dtype=uint8),
#  'fPHI': array([[2.88771],
#         [2.04032],
#         [5.38962],
#         ...,
#         [5.56478],
#         [1.8101 ],
#         [2.51839]]),
#  'fTHETA': array([[0.10897  ],
#         [0.0970378],
#         [0.107277 ],
#         ...,
#         [0.270176 ],
#         [0.166132 ],
#         [0.272713 ]])}

# %%
nn = range(1, 1001)
dfile = 'protons/CaloStrip/CaloStrip_pr_0p1_1500_rig_F0p8_10000000_1.mat'.format(fnum)
calo_events = calo_importer.import_data(os.path.join(dpath, dfile), events=nn)
# Out:
# .mat file loaded

# %%
# Изображение проекции калориметра
calo_events[6].plot()

# %%
Image('1.jpg')

# %%
Image('2.jpg')

# %%
def load_mat_data(mat_path):
    """Загружает данные из .mat или .npy файла с калориметра"""
    if mat_path.endswith(".npy"):
        return np.load(mat_path, allow_pickle=True).item()
    elif mat_path.endswith(".mat"):
        raw = scipy.io.loadmat(mat_path)
        return {k: v.squeeze() for k, v in raw.items() if not k.startswith("__")}
    else:
        raise ValueError("Unsupported file format")

def visualize_event(calo_data, event_id=0, scale=2.56, z_step=6.19, z_size=44, y_size=96, x_size=96):
    """Создает объем энерговыделения и визуализирует его вместе с теоретическим треком"""
    volume = np.zeros((z_size, y_size, x_size), dtype=np.float32)

    mask = calo_data['event_ID'] == event_id
    x_idx = calo_data['index_along_x'][mask].astype(int)
    y_idx = calo_data['index_along_y'][mask].astype(int)
    z_idx = calo_data['layer'][mask].astype(int)
    energy = calo_data['energy_release'][mask]

    for x, y, z, e in zip(x_idx, y_idx, z_idx, energy):
        if 0 <= x < x_size and 0 <= y < y_size and 0 <= z < z_size:
            volume[z, y, x] += e

    x0 = calo_data["X_0"][event_id]
    y0 = calo_data["Y_0"][event_id]
    phi = calo_data["phi_0"][event_id]
    theta = calo_data["theta_0"][event_id]
    zend = calo_data["Z_end"][event_id]

    x0_idx = int(np.clip(x0 / scale + x_size // 2, 0, x_size - 1))
    y0_idx = int(np.clip(y0 / scale + y_size // 2, 0, y_size - 1))

    t_end = zend / z_step
    t_vals = np.linspace(0, t_end, 100)
    vx = np.sin(theta) * np.cos(phi)
    vy = np.sin(theta) * np.sin(phi)
    vz = np.cos(theta)

    track_x = x0_idx + t_vals * vx / scale
    track_y = y0_idx + t_vals * vy / scale
    track_z = t_vals * vz

    mask = (track_x >= 0) & (track_x < x_size) & (track_y >= 0) & (track_y < y_size) & (track_z >= 0) & (track_z < z_size)
    track_x, track_y, track_z = track_x[mask], track_y[mask], track_z[mask]

    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    z_, y_, x_ = np.nonzero(volume > 0.1)
    e_ = volume[z_, y_, x_]
    ax.scatter(x_, y_, z_, c=e_, cmap='hot', s=5, alpha=0.5, label='Energy deposit')
    ax.plot(track_x, track_y, track_z, color='cyan', linewidth=2, label='True track')
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Layer (Z)")
    ax.set_title(f"Event ID: {event_id} — 3D Track and Energy Hits")
    ax.legend()
    plt.tight_layout()
    plt.show()

# Загрузка и визуализация из файла
file_path = "calorimeter_response.npy"
calo_data = load_mat_data(file_path)
visualize_event(calo_data, event_id=3)

# %% [markdown]
# | Объект | Размерность        | Значение                          |
# | ------ | ------------------ | --------------------------------- |
# | `x`    | 405 504 = 44×96×96 | Искомое векторное распределение   |
# | `b`    | 8 448 = 44×(96+96) | Вектор наблюдаемых проекций       |
# | `A`    | (8448, 405504)     | Разреженная матрица проецирования |

# %%
import numpy as np
import scipy.optimize
from scipy.sparse import lil_matrix

# Настройки объёма
Z, Y, X = 44, 96, 96
V = Z * Y * X  # размерность x
B = Z * (X + Y)  # размерность b

def build_projection_matrix(z_size=44, y_size=96, x_size=96):
    """
    Строит разреженную матрицу A: Ax = b,
    где b — вектор из проекций (по X и по Y).
    Сначала идут строки проекции по X (по оси i), затем по Y (по оси j).
    """
    A = lil_matrix((z_size * (x_size + y_size), z_size * y_size * x_size), dtype=np.float32)

    row = 0
    for z in range(z_size):
        # проекции по X (сумма по i → фиксированы j, k)
        for y in range(y_size):
            for x in range(x_size):
                col = z * y_size * x_size + y * x_size + x
                A[row, col] = 1.0
            row += 1
        # проекции по Y (сумма по j → фиксированы i, k)
        for x in range(x_size):
            for y in range(y_size):
                col = z * y_size * x_size + y * x_size + x
                A[row, col] = 1.0
            row += 1
    return A.tocsr()

# Получим реальные проекции
def get_volume_for_event(calo_data, event_id=0):
    mask = calo_data['event_ID'] == event_id
    x = calo_data['index_along_x'][mask].astype(int)
    y = calo_data['index_along_y'][mask].astype(int)
    z = calo_data['layer'][mask].astype(int)
    e = calo_data['energy_release'][mask]

    volume = np.zeros((Z, Y, X), dtype=np.float32)
    for xi, yi, zi, ei in zip(x, y, z, e):
        if 0 <= xi < X and 0 <= yi < Y and 0 <= zi < Z:
            volume[zi, yi, xi] += ei
    return volume

def compute_projections(volume):
    proj_x = np.sum(volume, axis=2).reshape(-1)  # (Z, Y) → flatten
    proj_y = np.sum(volume, axis=1).reshape(-1)  # (Z, X) → flatten
    return np.concatenate([proj_x, proj_y])  # (Z*(Y+X),)

# Загрузка данных
calo_data = np.load("calorimeter_response.npy", allow_pickle=True).item()
volume = get_volume_for_event(calo_data, event_id=0)
b = compute_projections(volume)
A = build_projection_matrix()

# Проверка размеров
A.shape, b.shape
# Out:
# ((8448, 405504), (8448,))

# %%
# Восстановление треков из проекций с регуляризацией (батч + логирование)
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix, lil_matrix
from math import atan2, acos
from sklearn.linear_model import LinearRegression

# Загрузка
calo_data = np.load("calorimeter_response.npy", allow_pickle=True).item()

def get_volume_for_event(calo_data, event_id=0, z_size=44, y_size=96, x_size=96):
    mask = calo_data['event_ID'] == event_id
    x = calo_data['index_along_x'][mask].astype(int)
    y = calo_data['index_along_y'][mask].astype(int)
    z = calo_data['layer'][mask].astype(int)
    e = calo_data['energy_release'][mask]
    volume = np.zeros((z_size, y_size, x_size), dtype=np.float32)
    for xi, yi, zi, ei in zip(x, y, z, e):
        if 0 <= xi < x_size and 0 <= yi < y_size and 0 <= zi < z_size:
            volume[zi, yi, xi] += ei
    return volume

def compute_projections(volume):
    return np.concatenate([np.sum(volume, axis=2).reshape(-1), np.sum(volume, axis=1).reshape(-1)])

def build_projection_matrix(Z, Y, X):
    A = lil_matrix((Z * (Y + X), Z * Y * X), dtype=np.float32)
    row = 0
    for z in range(Z):
        for y in range(Y):
            for x in range(X):
                col = z * Y * X + y * X + x
                A[row, col] = 1.0
            row += 1
        for x in range(X):
            for y in range(Y):
                col = z * Y * X + y * X + x
                A[row, col] = 1.0
            row += 1
    return A.tocsr()

def smoothness_matrix(Z, Y, X):
    rows, cols, data = [], [], []
    row_id = 0
    for z in range(Z - 1):
        for y in range(Y):
            for x_ in range(X):
                idx1 = z * Y * X + y * X + x_
                idx2 = (z + 1) * Y * X + y * X + x_
                rows += [row_id, row_id]
                cols += [idx1, idx2]
                data += [-1.0, 1.0]
                row_id += 1
    return csr_matrix((data, (rows, cols)), shape=(row_id, Z * Y * X))

def compute_track_angles(volume):
    Z, Y, X = volume.shape
    z_vals, x_centers, y_centers = [], [], []
    for z in range(Z):
        layer = volume[z]
        total = np.sum(layer)
        if total > 1e-6:
            y_coords, x_coords = np.indices(layer.shape)
            x_center = np.sum(x_coords * layer) / total
            y_center = np.sum(y_coords * layer) / total
            z_vals.append(z)
            x_centers.append(x_center)
            y_centers.append(y_center)
    z_vals = np.array(z_vals).reshape(-1, 1)
    reg_x = LinearRegression().fit(z_vals, x_centers)
    reg_y = LinearRegression().fit(z_vals, y_centers)
    dx, dy, dz = reg_x.coef_[0], reg_y.coef_[0], 1.0
    norm = np.sqrt(dx**2 + dy**2 + dz**2)
    return acos(dz / norm), atan2(dy, dx)

def get_true_angles(calo_data, event_id):
    theta = calo_data["theta_0"][event_id]
    phi = calo_data["phi_0"][event_id]
    vx = np.sin(theta) * np.cos(phi)
    vy = np.sin(theta) * np.sin(phi)
    vz = np.cos(theta)
    norm = np.sqrt(vx**2 + vy**2 + vz**2)
    return np.arccos(vz / norm), np.arctan2(vy, vx)

# === Параметры ===
Z, Y, X = 8, 32, 32
num_events = 10
lambda_reg = 0.1
D = smoothness_matrix(Z, Y, X)

theta_errors = []
phi_errors = []
cnt = 0

for event_id in range(1000):
    volume = get_volume_for_event(calo_data, event_id, Z, Y, X)
    b = compute_projections(volume)
    A = build_projection_matrix(Z, Y, X)

    mask = np.abs(b) > 1e-5
    max_b = np.max(b)
    used = np.count_nonzero(mask)
    if max_b > 0.1 and used > 5:
        status = "OK" 
        cnt += 1
    else:
        status = "weak"
    print(f"event {event_id}: max_b={max_b:.3e}, used={used} → {status}")

    if used == 0:
        continue

    A_sparse = csr_matrix(A[mask])
    b_clean = b[mask]

    x = cp.Variable(A_sparse.shape[1], nonneg=True)
    objective = cp.Minimize(cp.sum_squares(A_sparse @ x - b_clean) + lambda_reg * cp.sum_squares(D @ x))
    problem = cp.Problem(objective)
    problem.solve(solver=cp.OSQP, verbose=False)

    volume_hat = x.value.reshape((Z, Y, X))
    theta_hat, phi_hat = compute_track_angles(volume_hat)
    theta_true, phi_true = get_true_angles(calo_data, event_id)

    theta_errors.append(abs(theta_hat - theta_true))
    phi_errors.append(abs(phi_hat - phi_true))
# Out:
# event 0: max_b=0.000e+00, used=0 → weak
# event 1: max_b=7.136e+00, used=21 → OK
# event 2: max_b=0.000e+00, used=0 → weak
# event 3: max_b=1.313e-02, used=2 → weak
# event 4: max_b=0.000e+00, used=0 → weak
# event 5: max_b=0.000e+00, used=0 → weak
# event 6: max_b=0.000e+00, used=0 → weak
# event 7: max_b=0.000e+00, used=0 → weak
# event 8: max_b=0.000e+00, used=0 → weak
# event 9: max_b=0.000e+00, used=0 → weak
# event 10: max_b=0.000e+00, used=0 → weak
# event 11: max_b=0.000e+00, used=0 → weak
# event 12: max_b=0.000e+00, used=0 → weak
# event 13: max_b=0.000e+00, used=0 → weak
# event 14: max_b=0.000e+00, used=0 → weak
# event 15: max_b=0.000e+00, used=0 → weak
# event 16: max_b=0.000e+00, used=0 → weak
# event 17: max_b=0.000e+00, used=0 → weak
# event 18: max_b=0.000e+00, used=0 → weak
# event 19: max_b=1.305e-01, used=17 → OK
# event 20: max_b=0.000e+00, used=0 → weak
# event 21: max_b=0.000e+00, used=0 → weak
# event 22: max_b=5.677e-01, used=15 → OK
# event 23: max_b=3.918e+00, used=22 → OK
# event 24: max_b=0.000e+00, used=0 → weak
# event 25: max_b=0.000e+00, used=0 → weak
# event 26: max_b=0.000e+00, used=0 → weak
# event 27: max_b=0.000e+00, used=0 → weak
# event 28: max_b=0.000e+00, used=0 → weak
# event 29: max_b=0.000e+00, used=0 → weak
# event 30: max_b=0.000e+00, used=0 → weak
# event 31: max_b=0.000e+00, used=0 → weak
# event 32: max_b=0.000e+00, used=0 → weak
# event 33: max_b=0.000e+00, used=0 → weak
# event 34: max_b=0.000e+00, used=0 → weak
# event 35: max_b=0.000e+00, used=0 → weak
# event 36: max_b=0.000e+00, used=0 → weak
# event 37: max_b=0.000e+00, used=0 → weak
# event 38: max_b=0.000e+00, used=0 → weak
# event 39: max_b=0.000e+00, used=0 → weak
# event 40: max_b=0.000e+00, used=0 → weak
# event 41: max_b=0.000e+00, used=0 → weak
# event 42: max_b=4.703e+00, used=14 → OK
# event 43: max_b=0.000e+00, used=0 → weak
# event 44: max_b=2.161e-01, used=7 → OK
# event 45: max_b=0.000e+00, used=0 → weak
# event 46: max_b=0.000e+00, used=0 → weak
# event 47: max_b=0.000e+00, used=0 → weak
# event 48: max_b=0.000e+00, used=0 → weak
# event 49: max_b=0.000e+00, used=0 → weak
# event 50: max_b=1.760e-01, used=2 → weak
# event 51: max_b=0.000e+00, used=0 → weak
# event 52: max_b=0.000e+00, used=0 → weak
# event 53: max_b=0.000e+00, used=0 → weak
# event 54: max_b=0.000e+00, used=0 → weak
# event 55: max_b=0.000e+00, used=0 → weak
# event 56: max_b=0.000e+00, used=0 → weak
# event 57: max_b=4.473e-01, used=2 → weak
# event 58: max_b=0.000e+00, used=0 → weak
# event 59: max_b=0.000e+00, used=0 → weak
# event 60: max_b=0.000e+00, used=0 → weak
# event 61: max_b=0.000e+00, used=0 → weak
# event 62: max_b=0.000e+00, used=0 → weak
# event 63: max_b=0.000e+00, used=0 → weak
# event 64: max_b=3.907e+00, used=18 → OK
# event 65: max_b=0.000e+00, used=0 → weak
# event 66: max_b=0.000e+00, used=0 → weak
# event 67: max_b=0.000e+00, used=0 → weak
# event 68: max_b=0.000e+00, used=0 → weak
# event 69: max_b=0.000e+00, used=0 → weak
# event 70: max_b=0.000e+00, used=0 → weak
# event 71: max_b=8.828e-02, used=2 → weak
# event 72: max_b=3.028e-01, used=16 → OK
# event 73: max_b=0.000e+00, used=0 → weak
# event 74: max_b=1.010e+00, used=16 → OK
# event 75: max_b=2.417e-01, used=16 → OK
# event 76: max_b=1.595e-01, used=17 → OK
# event 77: max_b=0.000e+00, used=0 → weak
# event 78: max_b=0.000e+00, used=0 → weak
# event 79: max_b=0.000e+00, used=0 → weak
# event 80: max_b=0.000e+00, used=0 → weak
# event 81: max_b=0.000e+00, used=0 → weak
# event 82: max_b=0.000e+00, used=0 → weak
# event 83: max_b=0.000e+00, used=0 → weak
# event 84: max_b=0.000e+00, used=0 → weak
# event 85: max_b=0.000e+00, used=0 → weak
# event 86: max_b=0.000e+00, used=0 → weak
# event 87: max_b=0.000e+00, used=0 → weak
# event 88: max_b=3.971e-01, used=6 → OK
# event 89: max_b=0.000e+00, used=0 → weak
# event 90: max_b=5.765e-01, used=22 → OK
# event 91: max_b=0.000e+00, used=0 → weak
# event 92: max_b=0.000e+00, used=0 → weak
# event 93: max_b=0.000e+00, used=0 → weak
# event 94: max_b=4.604e-01, used=18 → OK
# event 95: max_b=0.000e+00, used=0 → weak
# event 96: max_b=0.000e+00, used=0 → weak
# event 97: max_b=0.000e+00, used=0 → weak
# event 98: max_b=0.000e+00, used=0 → weak
# event 99: max_b=0.000e+00, used=0 → weak
# event 100: max_b=6.327e-01, used=18 → OK
# event 101: max_b=0.000e+00, used=0 → weak
# event 102: max_b=0.000e+00, used=0 → weak
# event 103: max_b=0.000e+00, used=0 → weak
# event 104: max_b=0.000e+00, used=0 → weak
# event 105: max_b=0.000e+00, used=0 → weak
# event 106: max_b=0.000e+00, used=0 → weak
# event 107: max_b=0.000e+00, used=0 → weak
# event 108: max_b=1.855e-02, used=2 → weak
# event 109: max_b=0.000e+00, used=0 → weak
# event 110: max_b=0.000e+00, used=0 → weak
# event 111: max_b=0.000e+00, used=0 → weak
# event 112: max_b=1.731e-01, used=15 → OK
# event 113: max_b=0.000e+00, used=0 → weak
# event 114: max_b=2.963e+00, used=30 → OK
# event 115: max_b=0.000e+00, used=0 → weak
# event 116: max_b=0.000e+00, used=0 → weak
# event 117: max_b=0.000e+00, used=0 → weak
# event 118: max_b=0.000e+00, used=0 → weak
# event 119: max_b=0.000e+00, used=0 → weak
# event 120: max_b=0.000e+00, used=0 → weak
# event 121: max_b=2.513e-01, used=6 → OK
# event 122: max_b=0.000e+00, used=0 → weak
# event 123: max_b=0.000e+00, used=0 → weak
# event 124: max_b=0.000e+00, used=0 → weak
# event 125: max_b=6.717e-01, used=20 → OK
# event 126: max_b=0.000e+00, used=0 → weak
# event 127: max_b=3.160e-01, used=16 → OK
# event 128: max_b=0.000e+00, used=0 → weak
# event 129: max_b=0.000e+00, used=0 → weak
# event 130: max_b=0.000e+00, used=0 → weak
# event 131: max_b=0.000e+00, used=0 → weak
# event 132: max_b=1.057e-01, used=2 → weak
# event 133: max_b=0.000e+00, used=0 → weak
# event 134: max_b=0.000e+00, used=0 → weak
# event 135: max_b=6.680e-01, used=16 → OK
# event 136: max_b=0.000e+00, used=0 → weak
# event 137: max_b=2.560e-01, used=17 → OK
# event 138: max_b=0.000e+00, used=0 → weak
# event 139: max_b=0.000e+00, used=0 → weak
# event 140: max_b=0.000e+00, used=0 → weak
# event 141: max_b=0.000e+00, used=0 → weak
# event 142: max_b=0.000e+00, used=0 → weak
# event 143: max_b=0.000e+00, used=0 → weak
# event 144: max_b=0.000e+00, used=0 → weak
# event 145: max_b=0.000e+00, used=0 → weak
# event 146: max_b=0.000e+00, used=0 → weak
# event 147: max_b=0.000e+00, used=0 → weak
# event 148: max_b=0.000e+00, used=0 → weak
# event 149: max_b=0.000e+00, used=0 → weak
# event 150: max_b=0.000e+00, used=0 → weak
# event 151: max_b=0.000e+00, used=0 → weak
# event 152: max_b=0.000e+00, used=0 → weak
# event 153: max_b=0.000e+00, used=0 → weak
# event 154: max_b=0.000e+00, used=0 → weak
# event 155: max_b=0.000e+00, used=0 → weak
# event 156: max_b=0.000e+00, used=0 → weak
# event 157: max_b=0.000e+00, used=0 → weak
# event 158: max_b=0.000e+00, used=0 → weak
# event 159: max_b=0.000e+00, used=0 → weak
# event 160: max_b=0.000e+00, used=0 → weak
# event 161: max_b=0.000e+00, used=0 → weak
# event 162: max_b=0.000e+00, used=0 → weak
# event 163: max_b=3.035e-01, used=19 → OK
# event 164: max_b=5.469e-01, used=17 → OK
# event 165: max_b=0.000e+00, used=0 → weak
# event 166: max_b=0.000e+00, used=0 → weak
# event 167: max_b=0.000e+00, used=0 → weak
# event 168: max_b=0.000e+00, used=0 → weak
# event 169: max_b=4.881e-01, used=18 → OK
# event 170: max_b=0.000e+00, used=0 → weak
# event 171: max_b=1.572e+00, used=38 → OK
# event 172: max_b=1.210e-01, used=4 → weak
# event 173: max_b=0.000e+00, used=0 → weak
# event 174: max_b=0.000e+00, used=0 → weak
# event 175: max_b=1.848e+01, used=114 → OK
# event 176: max_b=2.386e+00, used=43 → OK
# event 177: max_b=0.000e+00, used=0 → weak
# event 178: max_b=2.713e+00, used=31 → OK
# event 179: max_b=0.000e+00, used=0 → weak
# event 180: max_b=0.000e+00, used=0 → weak
# event 181: max_b=3.784e-01, used=15 → OK
# event 182: max_b=0.000e+00, used=0 → weak
# event 183: max_b=0.000e+00, used=0 → weak
# event 184: max_b=0.000e+00, used=0 → weak
# event 185: max_b=0.000e+00, used=0 → weak
# event 186: max_b=2.963e-01, used=11 → OK
# event 187: max_b=0.000e+00, used=0 → weak
# event 188: max_b=0.000e+00, used=0 → weak
# event 189: max_b=0.000e+00, used=0 → weak
# event 190: max_b=0.000e+00, used=0 → weak
# event 191: max_b=0.000e+00, used=0 → weak
# event 192: max_b=0.000e+00, used=0 → weak
# event 193: max_b=0.000e+00, used=0 → weak
# event 194: max_b=0.000e+00, used=0 → weak
# event 195: max_b=0.000e+00, used=0 → weak
# event 196: max_b=0.000e+00, used=0 → weak
# event 197: max_b=0.000e+00, used=0 → weak
# event 198: max_b=0.000e+00, used=0 → weak
# event 199: max_b=0.000e+00, used=0 → weak
# event 200: max_b=0.000e+00, used=0 → weak
# event 201: max_b=0.000e+00, used=0 → weak
# event 202: max_b=0.000e+00, used=0 → weak
# event 203: max_b=0.000e+00, used=0 → weak
# event 204: max_b=2.226e+00, used=5 → weak
# event 205: max_b=0.000e+00, used=0 → weak
# event 206: max_b=0.000e+00, used=0 → weak
# event 207: max_b=0.000e+00, used=0 → weak
# event 208: max_b=0.000e+00, used=0 → weak
# event 209: max_b=1.231e+01, used=14 → OK
# event 210: max_b=3.553e-01, used=15 → OK
# event 211: max_b=0.000e+00, used=0 → weak
# event 212: max_b=0.000e+00, used=0 → weak
# event 213: max_b=0.000e+00, used=0 → weak
# event 214: max_b=2.806e-01, used=10 → OK
# event 215: max_b=0.000e+00, used=0 → weak
# event 216: max_b=0.000e+00, used=0 → weak
# event 217: max_b=0.000e+00, used=0 → weak
# event 218: max_b=0.000e+00, used=0 → weak
# event 219: max_b=0.000e+00, used=0 → weak
# event 220: max_b=0.000e+00, used=0 → weak
# event 221: max_b=0.000e+00, used=0 → weak
# event 222: max_b=0.000e+00, used=0 → weak
# event 223: max_b=0.000e+00, used=0 → weak
# event 224: max_b=0.000e+00, used=0 → weak
# event 225: max_b=5.401e-01, used=3 → weak
# event 226: max_b=1.372e-01, used=2 → weak
# event 227: max_b=5.437e-01, used=17 → OK
# event 228: max_b=0.000e+00, used=0 → weak
# event 229: max_b=0.000e+00, used=0 → weak
# event 230: max_b=0.000e+00, used=0 → weak
# event 231: max_b=0.000e+00, used=0 → weak
# event 232: max_b=0.000e+00, used=0 → weak
# event 233: max_b=5.732e+00, used=81 → OK
# event 234: max_b=0.000e+00, used=0 → weak
# event 235: max_b=0.000e+00, used=0 → weak
# event 236: max_b=1.149e+00, used=5 → weak
# event 237: max_b=0.000e+00, used=0 → weak
# event 238: max_b=0.000e+00, used=0 → weak
# event 239: max_b=0.000e+00, used=0 → weak
# event 240: max_b=0.000e+00, used=0 → weak
# event 241: max_b=0.000e+00, used=0 → weak
# event 242: max_b=0.000e+00, used=0 → weak
# event 243: max_b=5.462e-01, used=18 → OK
# event 244: max_b=0.000e+00, used=0 → weak
# event 245: max_b=0.000e+00, used=0 → weak
# event 246: max_b=0.000e+00, used=0 → weak
# event 247: max_b=0.000e+00, used=0 → weak
# event 248: max_b=0.000e+00, used=0 → weak
# event 249: max_b=0.000e+00, used=0 → weak
# event 250: max_b=0.000e+00, used=0 → weak
# event 251: max_b=0.000e+00, used=0 → weak
# event 252: max_b=0.000e+00, used=0 → weak
# event 253: max_b=0.000e+00, used=0 → weak
# event 254: max_b=0.000e+00, used=0 → weak
# event 255: max_b=0.000e+00, used=0 → weak
# event 256: max_b=0.000e+00, used=0 → weak
# event 257: max_b=0.000e+00, used=0 → weak
# event 258: max_b=0.000e+00, used=0 → weak
# event 259: max_b=0.000e+00, used=0 → weak
# event 260: max_b=0.000e+00, used=0 → weak
# event 261: max_b=0.000e+00, used=0 → weak
# event 262: max_b=0.000e+00, used=0 → weak
# event 263: max_b=0.000e+00, used=0 → weak
# event 264: max_b=0.000e+00, used=0 → weak
# event 265: max_b=0.000e+00, used=0 → weak
# event 266: max_b=1.881e-01, used=16 → OK
# event 267: max_b=3.715e-01, used=5 → weak
# event 268: max_b=0.000e+00, used=0 → weak
# event 269: max_b=0.000e+00, used=0 → weak
# event 270: max_b=6.146e-01, used=5 → weak
# event 271: max_b=0.000e+00, used=0 → weak
# event 272: max_b=0.000e+00, used=0 → weak
# event 273: max_b=2.459e-01, used=16 → OK
# event 274: max_b=0.000e+00, used=0 → weak
# event 275: max_b=0.000e+00, used=0 → weak
# event 276: max_b=2.926e-01, used=2 → weak
# event 277: max_b=0.000e+00, used=0 → weak
# event 278: max_b=0.000e+00, used=0 → weak
# event 279: max_b=0.000e+00, used=0 → weak
# event 280: max_b=0.000e+00, used=0 → weak
# event 281: max_b=0.000e+00, used=0 → weak
# event 282: max_b=0.000e+00, used=0 → weak
# event 283: max_b=0.000e+00, used=0 → weak
# event 284: max_b=2.408e-01, used=18 → OK
# event 285: max_b=0.000e+00, used=0 → weak
# event 286: max_b=0.000e+00, used=0 → weak
# event 287: max_b=0.000e+00, used=0 → weak
# event 288: max_b=0.000e+00, used=0 → weak
# event 289: max_b=0.000e+00, used=0 → weak
# event 290: max_b=0.000e+00, used=0 → weak
# event 291: max_b=0.000e+00, used=0 → weak
# event 292: max_b=0.000e+00, used=0 → weak
# event 293: max_b=0.000e+00, used=0 → weak
# event 294: max_b=0.000e+00, used=0 → weak
# event 295: max_b=0.000e+00, used=0 → weak
# event 296: max_b=0.000e+00, used=0 → weak
# event 297: max_b=0.000e+00, used=0 → weak
# event 298: max_b=0.000e+00, used=0 → weak
# event 299: max_b=0.000e+00, used=0 → weak
# event 300: max_b=0.000e+00, used=0 → weak
# event 301: max_b=1.361e-01, used=7 → OK
# event 302: max_b=0.000e+00, used=0 → weak
# event 303: max_b=0.000e+00, used=0 → weak
# event 304: max_b=0.000e+00, used=0 → weak
# event 305: max_b=0.000e+00, used=0 → weak
# event 306: max_b=0.000e+00, used=0 → weak
# event 307: max_b=0.000e+00, used=0 → weak
# event 308: max_b=0.000e+00, used=0 → weak
# event 309: max_b=0.000e+00, used=0 → weak
# event 310: max_b=0.000e+00, used=0 → weak
# event 311: max_b=0.000e+00, used=0 → weak
# event 312: max_b=0.000e+00, used=0 → weak
# event 313: max_b=2.627e-01, used=12 → OK
# event 314: max_b=1.202e-01, used=16 → OK
# event 315: max_b=0.000e+00, used=0 → weak
# event 316: max_b=0.000e+00, used=0 → weak
# event 317: max_b=0.000e+00, used=0 → weak
# event 318: max_b=0.000e+00, used=0 → weak
# event 319: max_b=2.464e-01, used=11 → OK
# event 320: max_b=0.000e+00, used=0 → weak
# event 321: max_b=0.000e+00, used=0 → weak
# event 322: max_b=0.000e+00, used=0 → weak
# event 323: max_b=0.000e+00, used=0 → weak
# event 324: max_b=0.000e+00, used=0 → weak
# event 325: max_b=0.000e+00, used=0 → weak
# event 326: max_b=0.000e+00, used=0 → weak
# event 327: max_b=0.000e+00, used=0 → weak
# event 328: max_b=0.000e+00, used=0 → weak
# event 329: max_b=2.930e+00, used=33 → OK
# event 330: max_b=0.000e+00, used=0 → weak
# event 331: max_b=0.000e+00, used=0 → weak
# event 332: max_b=0.000e+00, used=0 → weak
# event 333: max_b=0.000e+00, used=0 → weak
# event 334: max_b=0.000e+00, used=0 → weak
# event 335: max_b=0.000e+00, used=0 → weak
# event 336: max_b=1.806e-01, used=17 → OK
# event 337: max_b=1.485e+00, used=24 → OK
# event 338: max_b=0.000e+00, used=0 → weak
# event 339: max_b=0.000e+00, used=0 → weak
# event 340: max_b=5.713e-01, used=7 → OK
# event 341: max_b=0.000e+00, used=0 → weak
# event 342: max_b=0.000e+00, used=0 → weak
# event 343: max_b=0.000e+00, used=0 → weak
# event 344: max_b=2.032e-01, used=16 → OK
# event 345: max_b=0.000e+00, used=0 → weak
# event 346: max_b=0.000e+00, used=0 → weak
# event 347: max_b=1.414e-01, used=2 → weak
# event 348: max_b=4.624e-01, used=18 → OK
# event 349: max_b=0.000e+00, used=0 → weak
# event 350: max_b=0.000e+00, used=0 → weak
# event 351: max_b=0.000e+00, used=0 → weak
# event 352: max_b=0.000e+00, used=0 → weak
# event 353: max_b=0.000e+00, used=0 → weak
# event 354: max_b=0.000e+00, used=0 → weak
# event 355: max_b=0.000e+00, used=0 → weak
# event 356: max_b=0.000e+00, used=0 → weak
# event 357: max_b=0.000e+00, used=0 → weak
# event 358: max_b=0.000e+00, used=0 → weak
# event 359: max_b=0.000e+00, used=0 → weak
# event 360: max_b=0.000e+00, used=0 → weak
# event 361: max_b=0.000e+00, used=0 → weak
# event 362: max_b=0.000e+00, used=0 → weak
# event 363: max_b=0.000e+00, used=0 → weak
# event 364: max_b=0.000e+00, used=0 → weak
# event 365: max_b=0.000e+00, used=0 → weak
# event 366: max_b=0.000e+00, used=0 → weak
# event 367: max_b=0.000e+00, used=0 → weak
# event 368: max_b=0.000e+00, used=0 → weak
# event 369: max_b=0.000e+00, used=0 → weak
# event 370: max_b=0.000e+00, used=0 → weak
# event 371: max_b=0.000e+00, used=0 → weak
# event 372: max_b=0.000e+00, used=0 → weak
# event 373: max_b=0.000e+00, used=0 → weak
# event 374: max_b=0.000e+00, used=0 → weak
# event 375: max_b=0.000e+00, used=0 → weak
# event 376: max_b=0.000e+00, used=0 → weak
# event 377: max_b=0.000e+00, used=0 → weak
# event 378: max_b=4.385e-01, used=16 → OK
# event 379: max_b=0.000e+00, used=0 → weak
# event 380: max_b=0.000e+00, used=0 → weak
# event 381: max_b=0.000e+00, used=0 → weak
# event 382: max_b=7.855e-01, used=8 → OK
# event 383: max_b=0.000e+00, used=0 → weak
# event 384: max_b=0.000e+00, used=0 → weak
# event 385: max_b=0.000e+00, used=0 → weak
# event 386: max_b=0.000e+00, used=0 → weak
# event 387: max_b=0.000e+00, used=0 → weak
# event 388: max_b=0.000e+00, used=0 → weak
# event 389: max_b=0.000e+00, used=0 → weak
# event 390: max_b=0.000e+00, used=0 → weak
# event 391: max_b=0.000e+00, used=0 → weak
# event 392: max_b=0.000e+00, used=0 → weak
# event 393: max_b=0.000e+00, used=0 → weak
# event 394: max_b=1.747e-01, used=16 → OK
# event 395: max_b=0.000e+00, used=0 → weak
# event 396: max_b=0.000e+00, used=0 → weak
# event 397: max_b=0.000e+00, used=0 → weak
# event 398: max_b=2.992e-01, used=10 → OK
# event 399: max_b=5.089e-02, used=2 → weak
# event 400: max_b=0.000e+00, used=0 → weak
# event 401: max_b=0.000e+00, used=0 → weak
# event 402: max_b=0.000e+00, used=0 → weak
# event 403: max_b=0.000e+00, used=0 → weak
# event 404: max_b=0.000e+00, used=0 → weak
# event 405: max_b=0.000e+00, used=0 → weak
# event 406: max_b=0.000e+00, used=0 → weak
# event 407: max_b=0.000e+00, used=0 → weak
# event 408: max_b=0.000e+00, used=0 → weak
# event 409: max_b=0.000e+00, used=0 → weak
# event 410: max_b=3.094e-01, used=17 → OK
# event 411: max_b=4.087e-01, used=19 → OK
# event 412: max_b=0.000e+00, used=0 → weak
# event 413: max_b=0.000e+00, used=0 → weak
# event 414: max_b=0.000e+00, used=0 → weak
# event 415: max_b=2.596e+00, used=14 → OK
# event 416: max_b=1.799e-01, used=4 → weak
# event 417: max_b=0.000e+00, used=0 → weak
# event 418: max_b=0.000e+00, used=0 → weak
# event 419: max_b=0.000e+00, used=0 → weak
# event 420: max_b=2.513e-02, used=2 → weak
# event 421: max_b=0.000e+00, used=0 → weak
# event 422: max_b=0.000e+00, used=0 → weak
# event 423: max_b=0.000e+00, used=0 → weak
# event 424: max_b=0.000e+00, used=0 → weak
# event 425: max_b=0.000e+00, used=0 → weak
# event 426: max_b=0.000e+00, used=0 → weak
# event 427: max_b=0.000e+00, used=0 → weak
# event 428: max_b=0.000e+00, used=0 → weak
# event 429: max_b=0.000e+00, used=0 → weak
# event 430: max_b=0.000e+00, used=0 → weak
# event 431: max_b=3.195e-01, used=6 → OK
# event 432: max_b=0.000e+00, used=0 → weak
# event 433: max_b=0.000e+00, used=0 → weak
# event 434: max_b=0.000e+00, used=0 → weak
# event 435: max_b=0.000e+00, used=0 → weak
# event 436: max_b=0.000e+00, used=0 → weak
# event 437: max_b=0.000e+00, used=0 → weak
# event 438: max_b=0.000e+00, used=0 → weak
# event 439: max_b=0.000e+00, used=0 → weak
# event 440: max_b=0.000e+00, used=0 → weak
# event 441: max_b=0.000e+00, used=0 → weak
# event 442: max_b=0.000e+00, used=0 → weak
# event 443: max_b=0.000e+00, used=0 → weak
# event 444: max_b=0.000e+00, used=0 → weak
# event 445: max_b=0.000e+00, used=0 → weak
# event 446: max_b=0.000e+00, used=0 → weak
# event 447: max_b=0.000e+00, used=0 → weak
# event 448: max_b=0.000e+00, used=0 → weak
# event 449: max_b=0.000e+00, used=0 → weak
# event 450: max_b=2.472e-01, used=17 → OK
# event 451: max_b=0.000e+00, used=0 → weak
# event 452: max_b=0.000e+00, used=0 → weak
# event 453: max_b=0.000e+00, used=0 → weak
# event 454: max_b=0.000e+00, used=0 → weak
# event 455: max_b=0.000e+00, used=0 → weak
# event 456: max_b=0.000e+00, used=0 → weak
# event 457: max_b=0.000e+00, used=0 → weak
# event 458: max_b=0.000e+00, used=0 → weak
# event 459: max_b=1.444e-01, used=16 → OK
# event 460: max_b=0.000e+00, used=0 → weak
# event 461: max_b=1.726e+00, used=37 → OK
# event 462: max_b=0.000e+00, used=0 → weak
# event 463: max_b=0.000e+00, used=0 → weak
# event 464: max_b=0.000e+00, used=0 → weak
# event 465: max_b=0.000e+00, used=0 → weak
# event 466: max_b=0.000e+00, used=0 → weak
# event 467: max_b=0.000e+00, used=0 → weak
# event 468: max_b=0.000e+00, used=0 → weak
# event 469: max_b=0.000e+00, used=0 → weak
# event 470: max_b=0.000e+00, used=0 → weak
# event 471: max_b=1.172e+00, used=38 → OK
# event 472: max_b=1.571e-01, used=14 → OK
# event 473: max_b=0.000e+00, used=0 → weak
# event 474: max_b=0.000e+00, used=0 → weak
# event 475: max_b=0.000e+00, used=0 → weak
# event 476: max_b=1.794e+00, used=8 → OK
# event 477: max_b=0.000e+00, used=0 → weak
# event 478: max_b=1.852e-01, used=20 → OK
# event 479: max_b=0.000e+00, used=0 → weak
# event 480: max_b=0.000e+00, used=0 → weak
# event 481: max_b=0.000e+00, used=0 → weak
# event 482: max_b=0.000e+00, used=0 → weak
# event 483: max_b=0.000e+00, used=0 → weak
# event 484: max_b=0.000e+00, used=0 → weak
# event 485: max_b=0.000e+00, used=0 → weak
# event 486: max_b=4.744e-01, used=20 → OK
# event 487: max_b=7.404e-01, used=16 → OK
# event 488: max_b=0.000e+00, used=0 → weak
# event 489: max_b=4.798e-01, used=16 → OK
# event 490: max_b=0.000e+00, used=0 → weak
# event 491: max_b=0.000e+00, used=0 → weak
# event 492: max_b=0.000e+00, used=0 → weak
# event 493: max_b=0.000e+00, used=0 → weak
# event 494: max_b=0.000e+00, used=0 → weak
# event 495: max_b=0.000e+00, used=0 → weak
# event 496: max_b=0.000e+00, used=0 → weak
# event 497: max_b=0.000e+00, used=0 → weak
# event 498: max_b=5.359e-01, used=21 → OK
# event 499: max_b=4.521e-01, used=5 → weak
# event 500: max_b=1.166e+01, used=104 → OK
# event 501: max_b=0.000e+00, used=0 → weak
# event 502: max_b=0.000e+00, used=0 → weak
# event 503: max_b=1.393e+00, used=3 → weak
# event 504: max_b=0.000e+00, used=0 → weak
# event 505: max_b=0.000e+00, used=0 → weak
# event 506: max_b=0.000e+00, used=0 → weak
# event 507: max_b=2.954e-01, used=3 → weak
# event 508: max_b=0.000e+00, used=0 → weak
# event 509: max_b=0.000e+00, used=0 → weak
# event 510: max_b=1.524e-01, used=16 → OK
# event 511: max_b=0.000e+00, used=0 → weak
# event 512: max_b=0.000e+00, used=0 → weak
# event 513: max_b=1.693e+00, used=7 → OK
# event 514: max_b=0.000e+00, used=0 → weak
# event 515: max_b=0.000e+00, used=0 → weak
# event 516: max_b=0.000e+00, used=0 → weak
# event 517: max_b=0.000e+00, used=0 → weak
# event 518: max_b=0.000e+00, used=0 → weak
# event 519: max_b=0.000e+00, used=0 → weak
# event 520: max_b=0.000e+00, used=0 → weak
# event 521: max_b=0.000e+00, used=0 → weak
# event 522: max_b=0.000e+00, used=0 → weak
# event 523: max_b=0.000e+00, used=0 → weak
# event 524: max_b=0.000e+00, used=0 → weak
# event 525: max_b=2.046e-01, used=16 → OK
# event 526: max_b=0.000e+00, used=0 → weak
# event 527: max_b=0.000e+00, used=0 → weak
# event 528: max_b=3.678e-01, used=17 → OK
# event 529: max_b=0.000e+00, used=0 → weak
# event 530: max_b=0.000e+00, used=0 → weak
# event 531: max_b=0.000e+00, used=0 → weak
# event 532: max_b=0.000e+00, used=0 → weak
# event 533: max_b=0.000e+00, used=0 → weak
# event 534: max_b=0.000e+00, used=0 → weak
# event 535: max_b=2.603e-01, used=2 → weak
# event 536: max_b=4.999e-01, used=17 → OK
# event 537: max_b=0.000e+00, used=0 → weak
# event 538: max_b=3.487e-01, used=9 → OK
# event 539: max_b=1.674e+00, used=29 → OK
# event 540: max_b=5.333e-01, used=16 → OK
# event 541: max_b=0.000e+00, used=0 → weak
# event 542: max_b=3.944e-01, used=20 → OK
# event 543: max_b=0.000e+00, used=0 → weak
# event 544: max_b=0.000e+00, used=0 → weak
# event 545: max_b=0.000e+00, used=0 → weak
# event 546: max_b=0.000e+00, used=0 → weak
# event 547: max_b=0.000e+00, used=0 → weak
# event 548: max_b=0.000e+00, used=0 → weak
# event 549: max_b=0.000e+00, used=0 → weak
# event 550: max_b=0.000e+00, used=0 → weak
# event 551: max_b=0.000e+00, used=0 → weak
# event 552: max_b=0.000e+00, used=0 → weak
# event 553: max_b=0.000e+00, used=0 → weak
# event 554: max_b=0.000e+00, used=0 → weak
# event 555: max_b=1.339e-01, used=2 → weak
# event 556: max_b=2.121e-01, used=16 → OK
# event 557: max_b=0.000e+00, used=0 → weak
# event 558: max_b=0.000e+00, used=0 → weak
# event 559: max_b=0.000e+00, used=0 → weak
# event 560: max_b=0.000e+00, used=0 → weak
# event 561: max_b=0.000e+00, used=0 → weak
# event 562: max_b=0.000e+00, used=0 → weak
# event 563: max_b=0.000e+00, used=0 → weak
# event 564: max_b=1.204e+00, used=5 → weak
# event 565: max_b=1.298e-01, used=6 → OK
# event 566: max_b=0.000e+00, used=0 → weak
# event 567: max_b=0.000e+00, used=0 → weak
# event 568: max_b=0.000e+00, used=0 → weak
# event 569: max_b=2.407e-01, used=17 → OK
# event 570: max_b=0.000e+00, used=0 → weak
# event 571: max_b=0.000e+00, used=0 → weak
# event 572: max_b=0.000e+00, used=0 → weak
# event 573: max_b=0.000e+00, used=0 → weak
# event 574: max_b=0.000e+00, used=0 → weak
# event 575: max_b=0.000e+00, used=0 → weak
# event 576: max_b=0.000e+00, used=0 → weak
# event 577: max_b=0.000e+00, used=0 → weak
# event 578: max_b=0.000e+00, used=0 → weak
# event 579: max_b=0.000e+00, used=0 → weak
# event 580: max_b=0.000e+00, used=0 → weak
# event 581: max_b=0.000e+00, used=0 → weak
# event 582: max_b=0.000e+00, used=0 → weak
# event 583: max_b=0.000e+00, used=0 → weak
# event 584: max_b=0.000e+00, used=0 → weak
# event 585: max_b=2.455e+00, used=5 → weak
# event 586: max_b=0.000e+00, used=0 → weak
# event 587: max_b=3.326e-02, used=2 → weak
# event 588: max_b=0.000e+00, used=0 → weak
# event 589: max_b=0.000e+00, used=0 → weak
# event 590: max_b=0.000e+00, used=0 → weak
# event 591: max_b=6.095e-01, used=10 → OK
# event 592: max_b=0.000e+00, used=0 → weak
# event 593: max_b=0.000e+00, used=0 → weak
# event 594: max_b=0.000e+00, used=0 → weak
# event 595: max_b=0.000e+00, used=0 → weak
# event 596: max_b=0.000e+00, used=0 → weak
# event 597: max_b=1.295e-01, used=2 → weak
# event 598: max_b=0.000e+00, used=0 → weak
# event 599: max_b=1.512e-01, used=2 → weak
# event 600: max_b=0.000e+00, used=0 → weak
# event 601: max_b=0.000e+00, used=0 → weak
# event 602: max_b=6.273e-01, used=17 → OK
# event 603: max_b=9.700e-01, used=9 → OK
# event 604: max_b=0.000e+00, used=0 → weak
# event 605: max_b=2.160e-01, used=12 → OK
# event 606: max_b=0.000e+00, used=0 → weak
# event 607: max_b=0.000e+00, used=0 → weak
# event 608: max_b=0.000e+00, used=0 → weak
# event 609: max_b=4.834e-01, used=18 → OK
# event 610: max_b=0.000e+00, used=0 → weak
# event 611: max_b=0.000e+00, used=0 → weak
# event 612: max_b=0.000e+00, used=0 → weak
# event 613: max_b=0.000e+00, used=0 → weak
# event 614: max_b=0.000e+00, used=0 → weak
# event 615: max_b=0.000e+00, used=0 → weak
# event 616: max_b=0.000e+00, used=0 → weak
# event 617: max_b=0.000e+00, used=0 → weak
# event 618: max_b=0.000e+00, used=0 → weak
# event 619: max_b=0.000e+00, used=0 → weak
# event 620: max_b=0.000e+00, used=0 → weak
# event 621: max_b=0.000e+00, used=0 → weak
# event 622: max_b=0.000e+00, used=0 → weak
# event 623: max_b=0.000e+00, used=0 → weak
# event 624: max_b=0.000e+00, used=0 → weak
# event 625: max_b=0.000e+00, used=0 → weak
# event 626: max_b=0.000e+00, used=0 → weak
# event 627: max_b=0.000e+00, used=0 → weak
# event 628: max_b=0.000e+00, used=0 → weak
# event 629: max_b=0.000e+00, used=0 → weak
# event 630: max_b=0.000e+00, used=0 → weak
# event 631: max_b=5.223e-01, used=16 → OK
# event 632: max_b=0.000e+00, used=0 → weak
# event 633: max_b=1.572e-01, used=16 → OK
# event 634: max_b=0.000e+00, used=0 → weak
# event 635: max_b=0.000e+00, used=0 → weak
# event 636: max_b=0.000e+00, used=0 → weak
# event 637: max_b=0.000e+00, used=0 → weak
# event 638: max_b=3.293e+01, used=78 → OK
# event 639: max_b=2.203e-01, used=16 → OK
# event 640: max_b=0.000e+00, used=0 → weak
# event 641: max_b=0.000e+00, used=0 → weak
# event 642: max_b=0.000e+00, used=0 → weak
# event 643: max_b=0.000e+00, used=0 → weak
# event 644: max_b=0.000e+00, used=0 → weak
# event 645: max_b=0.000e+00, used=0 → weak
# event 646: max_b=0.000e+00, used=0 → weak
# event 647: max_b=7.090e-02, used=2 → weak
# event 648: max_b=0.000e+00, used=0 → weak
# event 649: max_b=0.000e+00, used=0 → weak
# event 650: max_b=0.000e+00, used=0 → weak
# event 651: max_b=0.000e+00, used=0 → weak
# event 652: max_b=0.000e+00, used=0 → weak
# event 653: max_b=0.000e+00, used=0 → weak
# event 654: max_b=0.000e+00, used=0 → weak
# event 655: max_b=0.000e+00, used=0 → weak
# event 656: max_b=0.000e+00, used=0 → weak
# event 657: max_b=6.717e-01, used=8 → OK
# event 658: max_b=0.000e+00, used=0 → weak
# event 659: max_b=0.000e+00, used=0 → weak
# event 660: max_b=0.000e+00, used=0 → weak
# event 661: max_b=0.000e+00, used=0 → weak
# event 662: max_b=0.000e+00, used=0 → weak
# event 663: max_b=0.000e+00, used=0 → weak
# event 664: max_b=0.000e+00, used=0 → weak
# event 665: max_b=0.000e+00, used=0 → weak
# event 666: max_b=0.000e+00, used=0 → weak
# event 667: max_b=0.000e+00, used=0 → weak
# event 668: max_b=0.000e+00, used=0 → weak
# event 669: max_b=0.000e+00, used=0 → weak
# event 670: max_b=5.720e-01, used=8 → OK
# event 671: max_b=0.000e+00, used=0 → weak
# event 672: max_b=0.000e+00, used=0 → weak
# event 673: max_b=0.000e+00, used=0 → weak
# event 674: max_b=0.000e+00, used=0 → weak
# event 675: max_b=0.000e+00, used=0 → weak
# event 676: max_b=4.137e-01, used=10 → OK
# event 677: max_b=0.000e+00, used=0 → weak
# event 678: max_b=0.000e+00, used=0 → weak
# event 679: max_b=0.000e+00, used=0 → weak
# event 680: max_b=0.000e+00, used=0 → weak
# event 681: max_b=0.000e+00, used=0 → weak
# event 682: max_b=1.394e-01, used=2 → weak
# event 683: max_b=0.000e+00, used=0 → weak
# event 684: max_b=3.414e-01, used=17 → OK
# event 685: max_b=0.000e+00, used=0 → weak
# event 686: max_b=0.000e+00, used=0 → weak
# event 687: max_b=3.956e-01, used=17 → OK
# event 688: max_b=0.000e+00, used=0 → weak
# event 689: max_b=0.000e+00, used=0 → weak
# event 690: max_b=0.000e+00, used=0 → weak
# event 691: max_b=0.000e+00, used=0 → weak
# event 692: max_b=3.948e-01, used=18 → OK
# event 693: max_b=0.000e+00, used=0 → weak
# event 694: max_b=0.000e+00, used=0 → weak
# event 695: max_b=0.000e+00, used=0 → weak
# event 696: max_b=0.000e+00, used=0 → weak
# event 697: max_b=0.000e+00, used=0 → weak
# event 698: max_b=0.000e+00, used=0 → weak
# event 699: max_b=0.000e+00, used=0 → weak
# event 700: max_b=0.000e+00, used=0 → weak
# event 701: max_b=0.000e+00, used=0 → weak
# event 702: max_b=0.000e+00, used=0 → weak
# event 703: max_b=0.000e+00, used=0 → weak
# event 704: max_b=0.000e+00, used=0 → weak
# event 705: max_b=1.408e+01, used=24 → OK
# event 706: max_b=0.000e+00, used=0 → weak
# event 707: max_b=0.000e+00, used=0 → weak
# event 708: max_b=0.000e+00, used=0 → weak
# event 709: max_b=0.000e+00, used=0 → weak
# event 710: max_b=0.000e+00, used=0 → weak
# event 711: max_b=0.000e+00, used=0 → weak
# event 712: max_b=0.000e+00, used=0 → weak
# event 713: max_b=1.000e+01, used=33 → OK
# event 714: max_b=0.000e+00, used=0 → weak
# event 715: max_b=0.000e+00, used=0 → weak
# event 716: max_b=0.000e+00, used=0 → weak
# event 717: max_b=0.000e+00, used=0 → weak
# event 718: max_b=0.000e+00, used=0 → weak
# event 719: max_b=0.000e+00, used=0 → weak
# event 720: max_b=0.000e+00, used=0 → weak
# event 721: max_b=0.000e+00, used=0 → weak
# event 722: max_b=0.000e+00, used=0 → weak
# event 723: max_b=0.000e+00, used=0 → weak
# event 724: max_b=0.000e+00, used=0 → weak
# event 725: max_b=0.000e+00, used=0 → weak
# event 726: max_b=0.000e+00, used=0 → weak
# event 727: max_b=4.015e-01, used=10 → OK
# event 728: max_b=0.000e+00, used=0 → weak
# event 729: max_b=0.000e+00, used=0 → weak
# event 730: max_b=0.000e+00, used=0 → weak
# event 731: max_b=0.000e+00, used=0 → weak
# event 732: max_b=0.000e+00, used=0 → weak
# event 733: max_b=0.000e+00, used=0 → weak
# event 734: max_b=0.000e+00, used=0 → weak
# event 735: max_b=0.000e+00, used=0 → weak
# event 736: max_b=0.000e+00, used=0 → weak
# event 737: max_b=0.000e+00, used=0 → weak
# event 738: max_b=0.000e+00, used=0 → weak
# event 739: max_b=0.000e+00, used=0 → weak
# event 740: max_b=0.000e+00, used=0 → weak
# event 741: max_b=0.000e+00, used=0 → weak
# event 742: max_b=0.000e+00, used=0 → weak
# event 743: max_b=1.515e-01, used=6 → OK
# event 744: max_b=0.000e+00, used=0 → weak
# event 745: max_b=0.000e+00, used=0 → weak
# event 746: max_b=0.000e+00, used=0 → weak
# event 747: max_b=0.000e+00, used=0 → weak
# event 748: max_b=0.000e+00, used=0 → weak
# event 749: max_b=0.000e+00, used=0 → weak
# event 750: max_b=0.000e+00, used=0 → weak
# event 751: max_b=0.000e+00, used=0 → weak
# event 752: max_b=0.000e+00, used=0 → weak
# event 753: max_b=0.000e+00, used=0 → weak
# event 754: max_b=0.000e+00, used=0 → weak
# event 755: max_b=1.516e-03, used=2 → weak
# event 756: max_b=0.000e+00, used=0 → weak
# event 757: max_b=0.000e+00, used=0 → weak
# event 758: max_b=0.000e+00, used=0 → weak
# event 759: max_b=0.000e+00, used=0 → weak
# event 760: max_b=2.949e+00, used=18 → OK
# event 761: max_b=0.000e+00, used=0 → weak
# event 762: max_b=4.347e-01, used=5 → weak
# event 763: max_b=0.000e+00, used=0 → weak
# event 764: max_b=0.000e+00, used=0 → weak
# event 765: max_b=0.000e+00, used=0 → weak
# event 766: max_b=0.000e+00, used=0 → weak
# event 767: max_b=2.296e-01, used=3 → weak
# event 768: max_b=0.000e+00, used=0 → weak
# event 769: max_b=2.214e-01, used=16 → OK
# event 770: max_b=0.000e+00, used=0 → weak
# event 771: max_b=0.000e+00, used=0 → weak
# event 772: max_b=6.921e-01, used=15 → OK
# event 773: max_b=0.000e+00, used=0 → weak
# event 774: max_b=0.000e+00, used=0 → weak
# event 775: max_b=0.000e+00, used=0 → weak
# event 776: max_b=1.037e+01, used=39 → OK
# event 777: max_b=0.000e+00, used=0 → weak
# event 778: max_b=0.000e+00, used=0 → weak
# event 779: max_b=0.000e+00, used=0 → weak
# event 780: max_b=0.000e+00, used=0 → weak
# event 781: max_b=0.000e+00, used=0 → weak
# event 782: max_b=6.116e-01, used=5 → weak
# event 783: max_b=5.324e-01, used=3 → weak
# event 784: max_b=0.000e+00, used=0 → weak
# event 785: max_b=0.000e+00, used=0 → weak
# event 786: max_b=0.000e+00, used=0 → weak
# event 787: max_b=0.000e+00, used=0 → weak
# event 788: max_b=0.000e+00, used=0 → weak
# event 789: max_b=0.000e+00, used=0 → weak
# event 790: max_b=0.000e+00, used=0 → weak
# event 791: max_b=0.000e+00, used=0 → weak
# event 792: max_b=0.000e+00, used=0 → weak
# event 793: max_b=0.000e+00, used=0 → weak
# event 794: max_b=0.000e+00, used=0 → weak
# event 795: max_b=0.000e+00, used=0 → weak
# event 796: max_b=0.000e+00, used=0 → weak
# event 797: max_b=0.000e+00, used=0 → weak
# event 798: max_b=0.000e+00, used=0 → weak
# event 799: max_b=0.000e+00, used=0 → weak
# event 800: max_b=0.000e+00, used=0 → weak
# event 801: max_b=0.000e+00, used=0 → weak
# event 802: max_b=0.000e+00, used=0 → weak
# event 803: max_b=0.000e+00, used=0 → weak
# event 804: max_b=2.539e-01, used=16 → OK
# event 805: max_b=0.000e+00, used=0 → weak
# event 806: max_b=0.000e+00, used=0 → weak
# event 807: max_b=0.000e+00, used=0 → weak
# event 808: max_b=1.160e+00, used=11 → OK
# event 809: max_b=0.000e+00, used=0 → weak
# event 810: max_b=0.000e+00, used=0 → weak
# event 811: max_b=0.000e+00, used=0 → weak
# event 812: max_b=0.000e+00, used=0 → weak
# event 813: max_b=0.000e+00, used=0 → weak
# event 814: max_b=0.000e+00, used=0 → weak
# event 815: max_b=0.000e+00, used=0 → weak
# event 816: max_b=0.000e+00, used=0 → weak
# event 817: max_b=0.000e+00, used=0 → weak
# event 818: max_b=8.320e-01, used=20 → OK
# event 819: max_b=0.000e+00, used=0 → weak
# event 820: max_b=0.000e+00, used=0 → weak
# event 821: max_b=0.000e+00, used=0 → weak
# event 822: max_b=3.755e-01, used=19 → OK
# event 823: max_b=0.000e+00, used=0 → weak
# event 824: max_b=1.069e-01, used=2 → weak
# event 825: max_b=0.000e+00, used=0 → weak
# event 826: max_b=0.000e+00, used=0 → weak
# event 827: max_b=0.000e+00, used=0 → weak
# event 828: max_b=0.000e+00, used=0 → weak
# event 829: max_b=0.000e+00, used=0 → weak
# event 830: max_b=0.000e+00, used=0 → weak
# event 831: max_b=0.000e+00, used=0 → weak
# event 832: max_b=3.284e-03, used=2 → weak
# event 833: max_b=0.000e+00, used=0 → weak
# event 834: max_b=4.308e+00, used=74 → OK
# event 835: max_b=0.000e+00, used=0 → weak
# event 836: max_b=7.064e+00, used=31 → OK
# event 837: max_b=0.000e+00, used=0 → weak
# event 838: max_b=0.000e+00, used=0 → weak
# event 839: max_b=0.000e+00, used=0 → weak
# event 840: max_b=0.000e+00, used=0 → weak
# event 841: max_b=0.000e+00, used=0 → weak
# event 842: max_b=0.000e+00, used=0 → weak
# event 843: max_b=4.090e-01, used=17 → OK
# event 844: max_b=0.000e+00, used=0 → weak
# event 845: max_b=0.000e+00, used=0 → weak
# event 846: max_b=0.000e+00, used=0 → weak
# event 847: max_b=0.000e+00, used=0 → weak
# event 848: max_b=0.000e+00, used=0 → weak
# event 849: max_b=0.000e+00, used=0 → weak
# event 850: max_b=0.000e+00, used=0 → weak
# event 851: max_b=0.000e+00, used=0 → weak
# event 852: max_b=0.000e+00, used=0 → weak
# event 853: max_b=0.000e+00, used=0 → weak
# event 854: max_b=0.000e+00, used=0 → weak
# event 855: max_b=0.000e+00, used=0 → weak
# event 856: max_b=0.000e+00, used=0 → weak
# event 857: max_b=0.000e+00, used=0 → weak
# event 858: max_b=0.000e+00, used=0 → weak
# event 859: max_b=3.146e-01, used=21 → OK
# event 860: max_b=0.000e+00, used=0 → weak
# event 861: max_b=0.000e+00, used=0 → weak
# event 862: max_b=5.113e-01, used=16 → OK
# event 863: max_b=0.000e+00, used=0 → weak
# event 864: max_b=0.000e+00, used=0 → weak
# event 865: max_b=0.000e+00, used=0 → weak
# event 866: max_b=0.000e+00, used=0 → weak
# event 867: max_b=1.973e+00, used=41 → OK
# event 868: max_b=2.929e-01, used=18 → OK
# event 869: max_b=0.000e+00, used=0 → weak
# event 870: max_b=0.000e+00, used=0 → weak
# event 871: max_b=0.000e+00, used=0 → weak
# event 872: max_b=0.000e+00, used=0 → weak
# event 873: max_b=0.000e+00, used=0 → weak
# event 874: max_b=0.000e+00, used=0 → weak
# event 875: max_b=0.000e+00, used=0 → weak
# event 876: max_b=0.000e+00, used=0 → weak
# event 877: max_b=0.000e+00, used=0 → weak
# event 878: max_b=0.000e+00, used=0 → weak
# event 879: max_b=0.000e+00, used=0 → weak
# event 880: max_b=0.000e+00, used=0 → weak
# event 881: max_b=0.000e+00, used=0 → weak
# event 882: max_b=0.000e+00, used=0 → weak
# event 883: max_b=0.000e+00, used=0 → weak
# event 884: max_b=0.000e+00, used=0 → weak
# event 885: max_b=1.057e-06, used=0 → weak
# event 886: max_b=8.480e-01, used=16 → OK
# event 887: max_b=0.000e+00, used=0 → weak
# event 888: max_b=0.000e+00, used=0 → weak
# event 889: max_b=0.000e+00, used=0 → weak
# event 890: max_b=1.402e-01, used=18 → OK
# event 891: max_b=0.000e+00, used=0 → weak
# event 892: max_b=0.000e+00, used=0 → weak
# event 893: max_b=0.000e+00, used=0 → weak
# event 894: max_b=0.000e+00, used=0 → weak
# event 895: max_b=0.000e+00, used=0 → weak
# event 896: max_b=0.000e+00, used=0 → weak
# event 897: max_b=0.000e+00, used=0 → weak
# event 898: max_b=0.000e+00, used=0 → weak
# event 899: max_b=0.000e+00, used=0 → weak
# event 900: max_b=0.000e+00, used=0 → weak
# event 901: max_b=0.000e+00, used=0 → weak
# event 902: max_b=0.000e+00, used=0 → weak
# event 903: max_b=0.000e+00, used=0 → weak
# event 904: max_b=0.000e+00, used=0 → weak
# event 905: max_b=0.000e+00, used=0 → weak
# event 906: max_b=0.000e+00, used=0 → weak
# event 907: max_b=0.000e+00, used=0 → weak
# event 908: max_b=0.000e+00, used=0 → weak
# event 909: max_b=0.000e+00, used=0 → weak
# event 910: max_b=3.520e-01, used=7 → OK
# event 911: max_b=0.000e+00, used=0 → weak
# event 912: max_b=0.000e+00, used=0 → weak
# event 913: max_b=0.000e+00, used=0 → weak
# event 914: max_b=0.000e+00, used=0 → weak
# event 915: max_b=0.000e+00, used=0 → weak
# event 916: max_b=0.000e+00, used=0 → weak
# event 917: max_b=2.867e-01, used=7 → OK
# event 918: max_b=5.441e-01, used=32 → OK
# event 919: max_b=2.358e-01, used=2 → weak
# event 920: max_b=0.000e+00, used=0 → weak
# event 921: max_b=0.000e+00, used=0 → weak
# event 922: max_b=0.000e+00, used=0 → weak
# event 923: max_b=0.000e+00, used=0 → weak
# event 924: max_b=0.000e+00, used=0 → weak
# event 925: max_b=0.000e+00, used=0 → weak
# event 926: max_b=0.000e+00, used=0 → weak
# event 927: max_b=0.000e+00, used=0 → weak
# event 928: max_b=0.000e+00, used=0 → weak
# event 929: max_b=0.000e+00, used=0 → weak
# event 930: max_b=0.000e+00, used=0 → weak
# event 931: max_b=0.000e+00, used=0 → weak
# event 932: max_b=0.000e+00, used=0 → weak
# event 933: max_b=0.000e+00, used=0 → weak
# event 934: max_b=0.000e+00, used=0 → weak
# event 935: max_b=0.000e+00, used=0 → weak
# event 936: max_b=0.000e+00, used=0 → weak
# event 937: max_b=0.000e+00, used=0 → weak
# event 938: max_b=0.000e+00, used=0 → weak
# event 939: max_b=0.000e+00, used=0 → weak
# event 940: max_b=0.000e+00, used=0 → weak
# event 941: max_b=0.000e+00, used=0 → weak
# event 942: max_b=4.665e-01, used=12 → OK
# event 943: max_b=1.796e-01, used=2 → weak
# event 944: max_b=0.000e+00, used=0 → weak
# event 945: max_b=0.000e+00, used=0 → weak
# event 946: max_b=0.000e+00, used=0 → weak
# event 947: max_b=0.000e+00, used=0 → weak
# event 948: max_b=7.031e-01, used=24 → OK
# event 949: max_b=9.656e-02, used=2 → weak
# event 950: max_b=0.000e+00, used=0 → weak
# event 951: max_b=0.000e+00, used=0 → weak
# event 952: max_b=0.000e+00, used=0 → weak
# event 953: max_b=0.000e+00, used=0 → weak
# event 954: max_b=0.000e+00, used=0 → weak
# event 955: max_b=1.930e+00, used=59 → OK
# event 956: max_b=1.388e+01, used=9 → OK
# event 957: max_b=6.651e-01, used=2 → weak
# event 958: max_b=0.000e+00, used=0 → weak
# event 959: max_b=0.000e+00, used=0 → weak
# event 960: max_b=0.000e+00, used=0 → weak
# event 961: max_b=4.154e-01, used=11 → OK
# event 962: max_b=0.000e+00, used=0 → weak
# event 963: max_b=0.000e+00, used=0 → weak
# event 964: max_b=0.000e+00, used=0 → weak
# event 965: max_b=0.000e+00, used=0 → weak
# event 966: max_b=0.000e+00, used=0 → weak
# event 967: max_b=3.985e-01, used=19 → OK
# event 968: max_b=0.000e+00, used=0 → weak
# event 969: max_b=0.000e+00, used=0 → weak
# event 970: max_b=0.000e+00, used=0 → weak
# event 971: max_b=0.000e+00, used=0 → weak
# event 972: max_b=0.000e+00, used=0 → weak
# event 973: max_b=0.000e+00, used=0 → weak
# event 974: max_b=0.000e+00, used=0 → weak
# event 975: max_b=0.000e+00, used=0 → weak
# event 976: max_b=0.000e+00, used=0 → weak
# event 977: max_b=0.000e+00, used=0 → weak
# event 978: max_b=0.000e+00, used=0 → weak
# event 979: max_b=1.205e+01, used=48 → OK
# event 980: max_b=0.000e+00, used=0 → weak
# event 981: max_b=0.000e+00, used=0 → weak
# event 982: max_b=0.000e+00, used=0 → weak
# event 983: max_b=0.000e+00, used=0 → weak
# event 984: max_b=0.000e+00, used=0 → weak
# event 985: max_b=0.000e+00, used=0 → weak
# event 986: max_b=0.000e+00, used=0 → weak
# event 987: max_b=0.000e+00, used=0 → weak
# event 988: max_b=0.000e+00, used=0 → weak
# event 989: max_b=0.000e+00, used=0 → weak
# event 990: max_b=0.000e+00, used=0 → weak
# event 991: max_b=5.145e-01, used=4 → weak
# event 992: max_b=0.000e+00, used=0 → weak
# event 993: max_b=2.767e-01, used=16 → OK
# event 994: max_b=0.000e+00, used=0 → weak
# event 995: max_b=3.633e+01, used=47 → OK
# event 996: max_b=0.000e+00, used=0 → weak
# event 997: max_b=0.000e+00, used=0 → weak
# event 998: max_b=0.000e+00, used=0 → weak
# event 999: max_b=0.000e+00, used=0 → weak
# 130

# %%
# === Визуализация ===
plt.plot(range(len(theta_errors)), theta_errors, label="theta error")
plt.plot(range(len(phi_errors)), phi_errors, label="phi error")
plt.xlabel("Event ID")
plt.ylabel("Angle error (radians)")
plt.legend()
plt.grid()
plt.title("Ошибка восстановления углов (Z=8, Y=X=32)")
plt.show()
print(cnt)
# Out:
# 130

# %%
import cvxpy as cp
from scipy.sparse import csr_matrix

# Построение TV-матрицы
def build_tv_matrix(Z, Y, X):
    rows, cols, data = [], [], []
    row_id = 0
    def add_diff(i, j):
        nonlocal row_id, rows, cols, data
        rows += [row_id, row_id]
        cols += [i, j]
        data += [-1.0, 1.0]
        row_id += 1
    for z in range(Z):
        for y in range(Y):
            for x in range(X):
                idx = z * Y * X + y * X + x
                if x + 1 < X: add_diff(idx, idx + 1)
                if y + 1 < Y: add_diff(idx, idx + X)
                if z + 1 < Z: add_diff(idx, idx + Y * X)
    return csr_matrix((data, (rows, cols)), shape=(row_id, Z * Y * X))

# === Оптимизация с TV-регуляризацией ===
Z, Y, X = 8, 32, 32
lambda_tv = 0.01
D_tv = build_tv_matrix(Z, Y, X)
event_id = 961
volume = get_volume_for_event(calo_data, event_id, Z, Y, X)
b = compute_projections(volume)
A = build_projection_matrix(Z, Y, X)
mask = np.abs(b) > 1e-5

if np.sum(mask) > 0:
    A_sparse = csr_matrix(A[mask])
    b_clean = b[mask]
    x = cp.Variable(A_sparse.shape[1], nonneg=True)
    objective = cp.Minimize(cp.sum_squares(A_sparse @ x - b_clean) + lambda_tv * cp.norm1(D_tv @ x))
    problem = cp.Problem(objective)
    problem.solve(solver=cp.OSQP, verbose=True)
    volume_tv = x.value.reshape((Z, Y, X))
    print("✔ Solver status:", problem.status)
    print("📉 Objective value:", problem.value)

    if x.value is not None:
        print("✅ Solution vector shape:", x.shape)
        print("📦 Volume shape:", (Z, Y, X))
        print("🔍 Max value in solution:", np.max(x.value))
    else:
        print("❌ No solution found.")
    
else:
    print(1)
    volume_tv = None
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) May 25 08:50:18 PM: Your problem has 8192 variables, 0 constraints, and 0 parameters.
# (CVXPY) May 25 08:50:18 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 25 08:50:18 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 25 08:50:18 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) May 25 08:50:18 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 25 08:50:18 PM: Compiling problem (target solver=OSQP).
# (CVXPY) May 25 08:50:18 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) May 25 08:50:18 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 25 08:50:18 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 25 08:50:18 PM: Applying reduction QpMatrixStuffing
# (CVXPY) May 25 08:50:18 PM: Applying reduction OSQP
# (CVXPY) May 25 08:50:18 PM: Finished problem compilation (took 5.688e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 25 08:50:18 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v1.0.0  -  Operator Splitting QP Solver
#               (c) The OSQP Developer Team
# -----------------------------------------------------------------
# problem:  variables n = 31243, constraints m = 54283
#           nnz(P) + nnz(A) = 146806
# settings: algebra = Built-in,
#           OSQPInt = 4 bytes, OSQPFloat = 8 bytes,
#           linear system solver = QDLDL v0.1.8,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive: 50 iterations),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25, duality gap: on),
#           time_limit: 1.00e+10 sec,
#           scaling: on (10 iterations), scaled_termination: off
#           warm starting: on, polishing: on,
# iter   objective    prim res   dual res   gap        rel kkt    rho         time
#    1  -1.8432e+03   8.00e+00   7.20e-01  -1.84e+03   8.00e+00   1.00e-01    6.99e-02s
#   50   1.0754e-05   1.17e-02   7.82e-07  -2.10e-03   1.17e-02   1.89e+00*   1.69e-01s
#  200   2.5547e-02   1.13e-03   1.44e-03  -1.68e-04   1.44e-03   2.61e-01*   5.10e-01s
#  400   2.7695e-02   1.63e-03   2.08e-05   1.51e-03   1.63e-03   2.61e-01    9.44e-01s
#  600   2.5335e-02   4.61e-04   1.23e-04  -8.64e-04   4.61e-04   2.61e-01    1.40e+00s
#  800   2.5130e-02   7.35e-04   5.71e-05  -1.15e-03   7.35e-04   2.61e-01    1.80e+00s
# 1000   2.6408e-02   4.58e-04   4.57e-05   1.02e-04   4.58e-04   2.61e-01    2.19e+00s
# 1200   2.6198e-02   3.69e-04   4.39e-05  -1.14e-04   3.69e-04   2.61e-01    2.58e+00s
# 1400   2.5768e-02   3.52e-04   9.02e-06  -5.72e-04   3.52e-04   2.61e-01    2.97e+00s
# 1600   2.6102e-02   3.30e-04   2.62e-05  -2.65e-04   3.30e-04   2.61e-01    3.36e+00s
# 1800   2.6307e-02   2.69e-04   2.33e-06  -6.94e-05   2.69e-04   2.61e-01    3.74e+00s
# 2000   2.6108e-02   2.99e-04   1.38e-05  -2.79e-04   2.99e-04   2.61e-01    4.13e+00s
# 2200   2.6055e-02   2.81e-04   3.35e-06  -3.49e-04   2.81e-04   2.61e-01    4.52e+00s
# 2400   2.6237e-02   4.38e-04   6.96e-06  -1.80e-04   4.38e-04   2.61e-01    4.92e+00s
# 2600   2.6365e-02   1.07e-04   1.96e-06  -5.55e-05   1.07e-04   2.61e-01    5.30e+00s
# 2800   2.6328e-02   1.03e-04   3.35e-06  -9.64e-05   1.03e-04   2.61e-01    5.69e+00s
# 3000   2.6326e-02   1.00e-04   1.15e-06  -1.04e-04   1.00e-04   2.61e-01    6.08e+00s
# 3200   2.6355e-02   9.70e-05   1.94e-06  -7.86e-05   9.70e-05   2.61e-01    6.47e+00s
# 3400   2.6356e-02   9.39e-05   9.25e-07  -8.14e-05   9.39e-05   2.61e-01    6.85e+00s
# 3600   2.6331e-02   9.12e-05   1.31e-06  -1.09e-04   9.12e-05   2.61e-01    7.24e+00s
# 3800   2.6324e-02   8.85e-05   4.13e-07  -1.21e-04   8.85e-05   2.61e-01    7.63e+00s
# 4000   2.6336e-02   9.75e-05   6.93e-07  -1.12e-04   9.75e-05   2.61e-01    8.02e+00s
# 4200   2.6348e-02   9.83e-05   4.97e-07  -1.03e-04   9.83e-05   2.61e-01    8.41e+00s
# 4400   2.6352e-02   9.49e-05   6.26e-07  -1.02e-04   9.49e-05   2.61e-01    8.80e+00s
# 4600   2.6358e-02   9.16e-05   3.88e-07  -9.85e-05   9.16e-05   2.61e-01    9.19e+00s
# 4800   2.6365e-02   8.88e-05   2.20e-07  -9.37e-05   8.88e-05   2.61e-01    9.57e+00s
# 5000   2.6368e-02   8.67e-05   1.99e-07  -9.34e-05   8.67e-05   2.61e-01    9.96e+00s
# 5200   2.6366e-02   8.50e-05   3.07e-07  -9.77e-05   8.50e-05   2.61e-01    1.03e+01s
# 5400   2.6364e-02   8.32e-05   2.73e-07  -1.01e-04   8.32e-05   2.61e-01    1.07e+01s
# 5600   2.6366e-02   8.11e-05   1.29e-07  -1.02e-04   8.11e-05   2.61e-01    1.11e+01s
# 5700   2.6367e-02   8.01e-05   4.27e-08  -1.02e-04   8.01e-05   1.75e+00*   1.13e+01s
# 5800   2.6378e-02   7.32e-05   4.56e-07  -9.73e-05   7.32e-05   1.75e+00    1.17e+01s
# 6000   2.6397e-02   6.17e-05   8.64e-07  -8.74e-05   6.17e-05   1.75e+00    1.21e+01s
# 6200   2.6413e-02   5.78e-05   9.03e-07  -7.78e-05   5.78e-05   1.75e+00    1.25e+01s
# 6400   2.6427e-02   5.70e-05   5.88e-07  -6.81e-05   5.70e-05   1.75e+00    1.29e+01s
# 6600   2.6439e-02   5.56e-05   1.52e-07  -5.95e-05   5.56e-05   1.75e+00    1.33e+01s
# 6800   2.6448e-02   5.79e-05   1.31e-07  -5.28e-05   5.79e-05   1.75e+00    1.37e+01s
# 7000   2.6455e-02   5.96e-05   1.85e-07  -4.70e-05   5.96e-05   1.75e+00    1.40e+01s
# 7200   2.6462e-02   5.97e-05   3.39e-07  -4.20e-05   5.97e-05   1.75e+00    1.44e+01s
# 7400   2.6468e-02   6.07e-05   9.64e-08  -3.74e-05   6.07e-05   1.75e+00    1.48e+01s
# 7550   2.6472e-02   6.08e-05   3.79e-08  -3.37e-05   6.08e-05   1.09e+01*   1.51e+01s
# 7600   2.6479e-02   5.84e-05   2.77e-06  -2.89e-05   5.84e-05   1.09e+01    1.53e+01s
# 7750   2.6496e-02   2.98e-05   2.07e-05  -1.38e-05   2.98e-05   2.03e+00*   1.56e+01s
# 7800   2.6492e-02   1.77e-04   8.60e-06  -1.50e-05   1.77e-04   2.03e+00    1.57e+01s
# 8000   2.6501e-02   5.41e-05   4.52e-06  -7.73e-06   5.41e-05   2.03e+00    1.61e+01s
# 8200   2.6502e-02   4.89e-05   3.23e-06  -6.47e-06   4.89e-05   2.03e+00    1.65e+01s
# 8400   2.6500e-02   2.37e-05   3.04e-06  -8.57e-06   2.37e-05   2.03e+00    1.69e+01s
# 8600   2.6501e-02   1.76e-05   2.51e-06  -7.86e-06   1.76e-05   2.03e+00    1.73e+01s
# 8800   2.6503e-02   3.19e-05   5.99e-07  -6.44e-06   3.19e-05   2.03e+00    1.77e+01s
# 8825   2.6505e-02   1.10e-05   1.84e-06  -3.81e-06   1.10e-05   2.03e+00    1.77e+01s
#
# status:               solved
# solution polishing:   unsuccessful
# number of iterations: 8825
# optimal objective:    0.0265
# dual objective:       0.0265
# duality gap:          -3.8101e-06
# primal-dual integral: 1.8441e+03
# run time:             1.78e+01s
# optimal rho estimate: 7.69e-01
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 25 08:50:36 PM: Problem status: optimal
# (CVXPY) May 25 08:50:36 PM: Optimal value: 2.655e-02
# (CVXPY) May 25 08:50:36 PM: Compilation took 5.688e-02 seconds
# (CVXPY) May 25 08:50:36 PM: Solver (including time spent in interface) took 1.779e+01 seconds
# ✔ Solver status: optimal
# 📉 Objective value: 0.026554780205551312
# ✅ Solution vector shape: (8192,)
# 📦 Volume shape: (8, 32, 32)
# 🔍 Max value in solution: 0.16860256773585436

# %%
for z in range(Z):
    plt.imshow(volume_tv[z], cmap="hot")
    plt.title(f"TV-reconstructed Z = {z}")
    plt.colorbar()
    plt.show()

# %%
# Построение матрицы сглаживания по оси Z
from scipy.sparse import csr_matrix

def build_z_smoothness_matrix(Z, Y, X):
    rows, cols, data = [], [], []
    row_id = 0
    for z in range(Z - 1):
        for y in range(Y):
            for x in range(X):
                idx1 = z * Y * X + y * X + x
                idx2 = (z + 1) * Y * X + y * X + x
                rows += [row_id, row_id]
                cols += [idx1, idx2]
                data += [-1.0, 1.0]
                row_id += 1
    return csr_matrix((data, (rows, cols)), shape=(row_id, Z * Y * X))

# === Параметры ===
lambda_l2 = 0.1  # сила регуляризации
D_z = build_z_smoothness_matrix(Z, Y, X)

# === Оптимизация ===
x_l2 = cp.Variable(A_sparse.shape[1], nonneg=True)
objective_l2 = cp.Minimize(cp.sum_squares(A_sparse @ x_l2 - b_clean) + lambda_l2 * cp.sum_squares(D_z @ x_l2))
problem_l2 = cp.Problem(objective_l2)
problem_l2.solve(solver=cp.OSQP, verbose=True)

volume_hat = x_l2.value.reshape((Z, Y, X))

# === Отрисовка ===
import matplotlib.pyplot as plt
for z in range(Z):
    plt.imshow(volume_hat[z], cmap="hot")
    plt.title(f"L2 Z-smooth: Layer Z={z}")
    plt.colorbar()
    plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) May 25 09:36:22 PM: Your problem has 8192 variables, 0 constraints, and 0 parameters.
# (CVXPY) May 25 09:36:22 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 25 09:36:22 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 25 09:36:22 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) May 25 09:36:22 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 25 09:36:22 PM: Compiling problem (target solver=OSQP).
# (CVXPY) May 25 09:36:22 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) May 25 09:36:22 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 25 09:36:22 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 25 09:36:22 PM: Applying reduction QpMatrixStuffing
# (CVXPY) May 25 09:36:22 PM: Applying reduction OSQP
# (CVXPY) May 25 09:36:22 PM: Finished problem compilation (took 5.415e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 25 09:36:22 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v1.0.0  -  Operator Splitting QP Solver
#               (c) The OSQP Developer Team
# -----------------------------------------------------------------
# problem:  variables n = 15371, constraints m = 15371
#           nnz(P) + nnz(A) = 37238
# settings: algebra = Built-in,
#           OSQPInt = 4 bytes, OSQPFloat = 8 bytes,
#           linear system solver = QDLDL v0.1.8,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive: 50 iterations),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25, duality gap: on),
#           time_limit: 1.00e+10 sec,
#           scaling: on (10 iterations), scaled_termination: off
#           warm starting: on, polishing: on,
# iter   objective    prim res   dual res   gap        rel kkt    rho         time
#    1   0.0000e+00   4.15e-01   7.20e+01  -5.62e+01   7.20e+01   1.00e-01    1.08e-02s
#   50   2.7144e-04   6.85e-10   6.63e-08  -6.60e-08   6.63e-08   1.00e-01    2.50e-02s
# plsh   2.7144e-04   2.78e-16   2.81e-16   2.22e-17   2.81e-16   --------    3.03e-02s
#
# status:               solved
# solution polishing:   successful
# number of iterations: 50
# optimal objective:    0.0003
# dual objective:       0.0003
# duality gap:          2.2226e-17
# primal-dual integral: 5.6192e+01
# run time:             3.03e-02s
# optimal rho estimate: 6.76e-04
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 25 09:36:22 PM: Problem status: optimal
# (CVXPY) May 25 09:36:22 PM: Optimal value: 2.714e-04
# (CVXPY) May 25 09:36:22 PM: Compilation took 5.415e-02 seconds
# (CVXPY) May 25 09:36:22 PM: Solver (including time spent in interface) took 3.651e-02 seconds

# %%
from scipy.sparse import csr_matrix

def build_tv_matrix(Z, Y, X):
    rows, cols, data = [], [], []
    row_id = 0

    def add_diff(i, j):
        nonlocal row_id
        rows.append(row_id)
        cols.append(i)
        data.append(-1.0)
        rows.append(row_id)
        cols.append(j)
        data.append(1.0)
        row_id += 1

    for z in range(Z):
        for y in range(Y):
            for x in range(X):
                idx = z * Y * X + y * X + x
                if x + 1 < X: add_diff(idx, idx + 1)
                if y + 1 < Y: add_diff(idx, idx + X)
                if z + 1 < Z: add_diff(idx, idx + Y * X)

    return csr_matrix((data, (rows, cols)), shape=(row_id, Z * Y * X))

# Пример вызова
D_tv = build_tv_matrix(16, 64, 64)
print("D_tv shape:", D_tv.shape)
# Out:
# D_tv shape: (190464, 65536)

# %%
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
from scipy.sparse import lil_matrix, csr_matrix

# === Настройки ===
Z, Y, X = 44, 96, 96
lambda_tv = 0.01
event_id = 961  # поменяй при необходимости

# === TV-регуляризатор ===
def build_tv_matrix(Z, Y, X):
    rows, cols, data = [], [], []
    row_id = 0
    def add_diff(i, j):
        nonlocal row_id
        rows.append(row_id); cols.append(i); data.append(-1.0)
        rows.append(row_id); cols.append(j); data.append(1.0)
        row_id += 1
    for z in range(Z):
        for y in range(Y):
            for x in range(X):
                idx = z * Y * X + y * X + x
                if x + 1 < X: add_diff(idx, idx + 1)
                if y + 1 < Y: add_diff(idx, idx + X)
                if z + 1 < Z: add_diff(idx, idx + Y * X)
    return csr_matrix((data, (rows, cols)), shape=(row_id, Z * Y * X))

# === Построение A ===
def build_projection_matrix(Z, Y, X):
    A = lil_matrix((Z * (Y + X), Z * Y * X), dtype=np.float32)
    row = 0
    for z in range(Z):
        for y in range(Y):
            for x in range(X):
                A[row, z * Y * X + y * X + x] = 1.0
            row += 1
        for x in range(X):
            for y in range(Y):
                A[row, z * Y * X + y * X + x] = 1.0
            row += 1
    return A.tocsr()

# === Обработка события ===
def get_volume_for_event(calo_data, event_id, Z, Y, X):
    mask = calo_data['event_ID'] == event_id
    x = calo_data['index_along_x'][mask].astype(int)
    y = calo_data['index_along_y'][mask].astype(int)
    z = calo_data['layer'][mask].astype(int)
    e = calo_data['energy_release'][mask]
    volume = np.zeros((Z, Y, X), dtype=np.float32)
    for xi, yi, zi, ei in zip(x, y, z, e):
        if 0 <= xi < X and 0 <= yi < Y and 0 <= zi < Z:
            volume[zi, yi, xi] += ei
    return volume

def compute_projections(volume):
    proj_x = np.sum(volume, axis=2).reshape(-1)
    proj_y = np.sum(volume, axis=1).reshape(-1)
    return np.concatenate([proj_x, proj_y])

# === Основной запуск ===
calo_data = np.load("calorimeter_response.npy", allow_pickle=True).item()
volume = get_volume_for_event(calo_data, event_id, Z, Y, X)
b = compute_projections(volume)
A = build_projection_matrix(Z, Y, X)
mask = np.abs(b) > 1e-5

if np.sum(mask) == 0:
    print("❌ No valid projections for this event.")
    exit()

A_sparse = csr_matrix(A[mask])
b_clean = b[mask]
D_tv = build_tv_matrix(Z, Y, X)

x = cp.Variable(A_sparse.shape[1], nonneg=True)
objective = cp.Minimize(cp.sum_squares(A_sparse @ x - b_clean) + lambda_tv * cp.norm1(D_tv @ x))
problem = cp.Problem(objective)
problem.solve(solver=cp.OSQP, verbose=True)

volume_tv = x.value.reshape((Z, Y, X))

# === Визуализация первых 10 слоёв ===
for z in range(min(10, Z)):
    plt.imshow(volume_tv[z], cmap="hot")
    plt.title(f"TV reconstruction Z = {z}")
    plt.colorbar()
    plt.show()
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.6.5
# ===============================================================================
# (CVXPY) May 25 11:13:45 PM: Your problem has 405504 variables, 0 constraints, and 0 parameters.
# (CVXPY) May 25 11:13:45 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 25 11:13:45 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 25 11:13:45 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# (CVXPY) May 25 11:13:45 PM: Your problem is compiled with the CPP canonicalization backend.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 25 11:13:45 PM: Compiling problem (target solver=OSQP).
# (CVXPY) May 25 11:13:45 PM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) May 25 11:13:45 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 25 11:13:45 PM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 25 11:13:45 PM: Applying reduction QpMatrixStuffing
# (CVXPY) May 25 11:13:47 PM: Applying reduction OSQP
# (CVXPY) May 25 11:13:47 PM: Finished problem compilation (took 1.967e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 25 11:13:47 PM: Invoking solver OSQP  to obtain a solution.
# -----------------------------------------------------------------
#            OSQP v1.0.0  -  Operator Splitting QP Solver
#               (c) The OSQP Developer Team
# -----------------------------------------------------------------
# problem:  variables n = 1604363, constraints m = 2803211
#           nnz(P) + nnz(A) = 7599670
# settings: algebra = Built-in,
#           OSQPInt = 4 bytes, OSQPFloat = 8 bytes,
#           linear system solver = QDLDL v0.1.8,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive: 50 iterations),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25, duality gap: on),
#           time_limit: 1.00e+10 sec,
#           scaling: on (10 iterations), scaled_termination: off
#           warm starting: on, polishing: on,
# iter   objective    prim res   dual res   gap        rel kkt    rho         time
#    1  -9.5907e+04   8.00e+00   7.20e-01  -9.59e+04   8.00e+00   1.00e-01    1.28e+03s
#   50   6.5378e-05   3.98e-03   3.05e-07  -6.75e-04   3.98e-03   1.77e+00*   1.79e+03s
#  200   1.4881e-02   3.34e-03   6.71e-04  -9.74e-03   3.34e-03   1.77e+00    4.63e+03s
#  350   2.5045e-02   6.63e-04   6.73e-04  -1.09e-03   6.73e-04   2.70e-01*   5.62e+03s
# Solver interrupted
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Cell In[43], line 80
#      78 objective = cp.Minimize(cp.sum_squares(A_sparse @ x - b_clean) + lambda_tv * cp.norm1(D_tv @ x))
#      79 problem = cp.Problem(objective)
# ---> 80 problem.solve(solver=cp.OSQP, verbose=True)
#      82 volume_tv = x.value.reshape((Z, Y, X))
#      84 # === Визуализация первых 10 слоёв ===
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/cvxpy/problems/problem.py:600, in Problem.solve(self, *args, **kwargs)
#     597         raise ValueError(
#     598             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     599     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 600 return solve_func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/cvxpy/problems/problem.py:1187, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1185 end = time.time()
#    1186 self._solve_time = end - start
# -> 1187 self.unpack_results(solution, solving_chain, inverse_data)
#    1188 if verbose:
#    1189     print(_FOOTER)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/cvxpy/problems/problem.py:1512, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1510     warnings.warn(INF_OR_UNB_MESSAGE)
#    1511 if solution.status in s.ERROR:
# -> 1512     raise error.SolverError(
#    1513             "Solver '%s' failed. " % chain.solver.name() +
#    1514             "Try another solver, or solve with verbose=True for more "
#    1515             "information.")
#    1517 self.unpack(solution)
#    1518 self._solver_stats = SolverStats.from_dict(self._solution.attr,
#    1519                                  chain.solver.name())
#
# SolverError: Solver 'OSQP' failed. Try another solver, or solve with verbose=True for more information.

# %%
# целевая функция с мягкими ограничениями, где 
# error_c - штраф за отклонение от c_jk
# error_d - штраф за отклонение от d_ik

def objective(x):
    x_ijk = x.reshape((I, J, K))
    error_c = np.sum((np.sum(x_ijk, axis=0) - c_jk) ** 2)  
    error_d = np.sum((np.sum(x_ijk, axis=1) - d_ik) ** 2)  
    return error_c + error_d

# %%
numm = 130
theta_0 = data['theta_0'][0, numm]
phi_0 = data['phi_0'][0, numm]
X_0 = data['X_0'][0, numm]
Y_0 = data['Y_0'][0, numm]
Z_end = data['Z_end'][0, numm]

x_projection = calo_events[numm].x_projection()
y_projection = calo_events[numm].y_projection()

I = 22
J = 22
K = 96 
x0 = np.ones(I * J * K)

c_jk = np.zeros((J, K))  
d_ik = np.zeros((I, K))  

for j in range(J):
    for k in range(K):
        if x_projection[j, k] != 0:
            c_jk[j, k] = x_projection[j, k]  
        if y_projection[j, k] != 0:
            d_ik[j, k] = y_projection[j, k]  
            
# ограничения (все значения должны быть неотрицательными)
bounds = [(0, None) for _ in range(I * J * K)]

#res = minimize(objective, x0, method='trust-constr', bounds=bounds, options={'disp': True, 'maxiter': 1000})
# res = minimize(objective, x0, method='L-BFGS-B', bounds=bounds, options={'disp': True, 'maxiter': 1000, 'maxfun': 100000})


#if res.success:
 #   x_ijk = res.x.reshape((I, J, K))
  #  print("Решение найдено")
#else:
 #   print("Решение не найдено:", res.message)

if res.success:
    x_ijk = res.reshape((I,J,K))

# %%
res1 = minimize(
    objective, x0, 
    method='trust-constr', 
    bounds=bounds,
    options={
        'disp': True, 
        'maxiter': 500, 
        'gtol': 1e-4,
        'verbose': 3  # Уровень детализации
    }
)

if res1.success:
    x_ijk = res1.x.reshape((I, J, K))
    print("Решение найдено")
else:
    print("Решение не найдено:", res1.message)

# %%
np.set_printoptions(threshold=np.inf)
c_jk

# %%
print(c_jk, d_ik, x_ijk.min(),x_ijk.max())

# %%
theta_rad = np.radians(theta_0)
phi_rad = np.radians(phi_0)

steps = 50  
t = np.linspace(0, , steps) 

X = X_0 + t * (Z_end - X_0) * np.sin(theta_rad) * np.cos(phi_rad)
Y = Y_0 + t * (Z_end - Y_0) * np.sin(theta_rad) * np.sin(phi_rad)
Z = Z_end * t * x_ijk[0, 0, :]  * np.cos(theta_rad)

sizes = np.mean(x_ijk, axis=(0, 1))  
sizes = sizes[:steps]  
if sizes.shape[0] < steps: 
    sizes = np.pad(sizes, (0, steps - sizes.shape[0]), 'edge')

print("Размерность X:", len(X), ", Размерность Y:", len(Y), ", Размерность Z:", len(Z))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(X, Y, Z, s=sizes * 10, c=sizes, cmap='viridis', alpha=0.7)

ax.set_xlabel('X координаты')
ax.set_ylabel('Y координаты')
ax.set_zlabel('Z координаты')
ax.set_title('3D Модель Полета Частицы')

cbar = plt.colorbar(scatter)
cbar.set_label('Размеры точек')
plt.show()

# %%
# Углы в радианах
theta_rad = np.radians(theta_0)
phi_rad = np.radians(phi_0)

# Задаем новые пределы для t
t_max = Z_end / np.cos(theta_rad)
steps = 50  
t = np.linspace(0, t_max, steps)  # Изменяем значение t от 0 до t_max

# Обновляем формулы для X, Y и Z
X = X_0 + t * np.sin(theta_rad) * np.cos(phi_rad)
Y = Y_0 + t * np.sin(theta_rad) * np.sin(phi_rad)
Z = t * np.cos(theta_rad)  # Обновленная формула для Z(t)

sizes = np.mean(x_ijk, axis=(0, 1))  
sizes = sizes[:steps]  
if sizes.shape[0] < steps: 
    sizes = np.pad(sizes, (0, steps - sizes.shape[0]), 'edge')

print("Размерность X:", len(X), ", Размерность Y:", len(Y), ", Размерность Z:", len(Z))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(X, Y, Z, s=sizes * 10, c=sizes, cmap='viridis', alpha=0.7)

ax.set_xlabel('X координаты')
ax.set_ylabel('Y координаты')
ax.set_zlabel('Z координаты')
ax.set_title('3D Модель Полета Частицы')

cbar = plt.colorbar(scatter)
cbar.set_label('Размеры точек')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

# Предполагаем, что res уже получен после оптимизации и res.success == True
if res1.success:
    x_ijk = res1.x.reshape((I, J, K))  # Преобразуем решение в трёхмерный массив
    print("Решение найдено")
else:
    print("Решение не найдено:", res.message)
    exit()

# Преобразование углов в радианы для параметризации
theta_rad = np.radians(theta_0)
phi_rad = np.radians(phi_0)

# Параметр t, представляющий положение частицы вдоль трека
steps = 50  # Количество шагов для визуализации
t = np.linspace(0, 1, steps)

# Использование оптимизированных значений для определения координат X, Y, Z
# Координаты X и Y зависят от углов и параметра t, а также от энерговыделений из x_ijk
X = X_0 + t * (Z_end - X_0) * np.sin(theta_rad) * np.cos(phi_rad) * np.mean(x_ijk, axis=(1, 2))[:steps]
Y = Y_0 + t * (Z_end - Y_0) * np.sin(theta_rad) * np.sin(phi_rad) * np.mean(x_ijk, axis=(0, 2))[:steps]
Z = Z_end * t * np.mean(x_ijk, axis=(0, 1))[:steps]  # Используем среднее распределение по слоям для определения глубины

# Использование данных энерговыделений для задания размеров точек и их цветовой кодировки
sizes = np.mean(x_ijk, axis=(0, 1))  # Среднее значение энерговыделений по слоям для оси глубины
sizes = sizes[:steps]
if sizes.shape[0] < steps:  # Если значений меньше, чем шагов t, дополняем
    sizes = np.pad(sizes, (0, steps - sizes.shape[0]), 'edge')

# Печать размерностей для проверки
print("Размерность X:", len(X), ", Размерность Y:", len(Y), ", Размерность Z:", len(Z))

# Визуализация 3D траектории частицы
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Построение трека с использованием рассчитанных размеров и цветовой кодировки
scatter = ax.scatter(X, Y, Z, s=sizes * 10, c=sizes, cmap='viridis', alpha=0.7)

# Оформление графика
ax.set_xlabel('X координаты')
ax.set_ylabel('Y координаты')
ax.set_zlabel('Z координаты')
ax.set_title('3D Модель Полета Частицы')

# Добавление цветовой шкалы для представления интенсивности
cbar = plt.colorbar(scatter)
cbar.set_label('Размеры точек')
plt.show()

# %%
for i in range(calo_events[20].x_projection().shape[0]):
    print("слой {}: {}".format(i+1, calo_events[20].x_projection()[i, :]))

# %%
# построение вектора v
v_x = np.sin(theta_0) * np.cos(phi_0)
v_y = np.sin(theta_0) * np.sin(phi_0)
v_z = np.cos(theta_0)

t_end = Z_end / v_z

print("Векторы v:", v_x, v_y, v_z)
print("t_end:", t_end)

# %%
print(data['X_0'][0,20], data['Y_0'][0,20])

# %%
x_projection = calo_events[20].x_projection()
y_projection = calo_events[20].y_projection()

x_projection
